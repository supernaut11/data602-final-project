# %%
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 25)

# %% [markdown]
# # Setting up the environment
#
# The next couple cells define global variables used throughout the notebook and ingest the training data that will be used to build a data model.

# %%
import os

# Set up some variables for the training data paths
BASE_DATA_PATH = os.path.join('..', 'data')
TRAIN_DATA_PATH = os.path.join(BASE_DATA_PATH, 'train')

TRAINING_PROVIDERS_PATH = os.path.join(TRAIN_DATA_PATH, 'Train-1542865627584.csv')
TRAINING_INPATIENT_PATH = os.path.join(TRAIN_DATA_PATH, 
    'Train_Inpatientdata-1542865627584.csv')
TRAINING_OUTPATIENT_PATH = os.path.join(TRAIN_DATA_PATH, 
    'Train_Outpatientdata-1542865627584.csv')
TRAINING_BENEFICIARY_PATH = os.path.join(TRAIN_DATA_PATH, 
    'Train_Beneficiarydata-1542865627584.csv')

# Defines the default behavior for responding to values that do not exist in data set
DEFAULT_NA_VALUE = "None"

# %%
# Read all of the training data

# List of providers
train_providers = pd.read_csv(TRAINING_PROVIDERS_PATH)

# Provides insights about the claims filed for those patients who are admitted in the hospitals
train_inpatient = pd.read_csv(TRAINING_INPATIENT_PATH)

# Provides details about the claims filed for those patients who visit hospitals and not admitted in it
train_outpatient = pd.read_csv(TRAINING_OUTPATIENT_PATH)

# Contains beneficiary KYC details like health conditions, region they belong to
train_beneficiary = pd.read_csv(TRAINING_BENEFICIARY_PATH)

# %%
# How similar are the inpatient/outpatient data? Let's see how many columns are
# unique between the two data sets
inp_unique_cols = [x for x in train_inpatient.columns if x not in train_outpatient.columns]
print(f'Unique columns in inpatient: {inp_unique_cols}')

outp_unique_cols = [x for x in train_outpatient.columns if x not in train_inpatient.columns]
print(f'Unique columns in outpatient: {outp_unique_cols}')
# Out:
# Unique columns in inpatient: ['AdmissionDt', 'DischargeDt', 'DiagnosisGroupCode']
# Unique columns in outpatient: []

# %% [markdown]
# # Merging claim data sets
#
# Based on what we know about the columns in the inpatient/outpatient tables, we can safely merge those datasets with minimal disruption. Recommend combining all of the claims into a single dataframe that has all of the data from each table with the following columns added:
# - Additional column for inpatient vs outpatient flag
# - Columns unique to inpatient (i.e., AdmissionDt, DischargeDt, DiagnosisGroupCode)

# %%
# Add a flag to each of the data sets to indicate whether they came from the
# inpatient vs. outpatient frames
train_inpatient['In/Out'] = 'In'
train_outpatient['In/Out'] = 'Out'

# Use the concat operation to create a union of the two data sets. This 
# automatically handles any missing columns between the two sets, so no need
# to manually add missing columns to the outpatient data first.
train_claims = pd.concat([train_inpatient, train_outpatient], ignore_index=True)

train_claims
# Out:
#             BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0        BENE11001   CLM46614   2009-04-12  2009-04-18  PRV55912
# 1        BENE11001   CLM66048   2009-08-31  2009-09-02  PRV55907
# 2        BENE11001   CLM68358   2009-09-17  2009-09-20  PRV56046
# 3        BENE11011   CLM38412   2009-02-14  2009-02-22  PRV52405
# 4        BENE11014   CLM63689   2009-08-13  2009-08-30  PRV56614
# ...            ...        ...          ...         ...       ...
# 558206  BENE159198  CLM510792   2009-08-06  2009-08-06  PRV53699
# 558207  BENE159198  CLM551294   2009-08-29  2009-08-29  PRV53702
# 558208  BENE159198  CLM596444   2009-09-24  2009-09-24  PRV53676
# 558209  BENE159198  CLM636992   2009-10-18  2009-10-18  PRV53689
# 558210  BENE159198  CLM686139   2009-11-17  2009-11-18  PRV53689
#
#         InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                        26000          PHY390922                NaN
# 1                         5000          PHY318495          PHY318495
# 2                         5000          PHY372395                NaN
# 3                         5000          PHY369659          PHY392961
# 4                        10000          PHY379376          PHY398258
# ...                        ...                ...                ...
# 558206                     800          PHY364188          PHY364188
# 558207                     400          PHY423019          PHY332284
# 558208                      60          PHY361063                NaN
# 558209                      70          PHY403198                NaN
# 558210                      80          PHY419379                NaN
#
#        OtherPhysician AdmissionDt ClmAdmitDiagnosisCode  DeductibleAmtPaid  \
# 0                 NaN  2009-04-12                  7866             1068.0
# 1                 NaN  2009-08-31                  6186             1068.0
# 2           PHY324689  2009-09-17                 29590             1068.0
# 3           PHY349768  2009-02-14                   431             1068.0
# 4                 NaN  2009-08-13                 78321             1068.0
# ...               ...         ...                   ...                ...
# 558206      PHY385752         NaN                   NaN                0.0
# 558207            NaN         NaN                   NaN                0.0
# 558208            NaN         NaN                   NaN                0.0
# 558209      PHY419379         NaN                   NaN                0.0
# 558210      PHY419379         NaN                   NaN                0.0
#
#        DischargeDt DiagnosisGroupCode ClmDiagnosisCode_1 ClmDiagnosisCode_2  \
# 0       2009-04-18                201               1970               4019
# 1       2009-09-02                750               6186               2948
# 2       2009-09-20                883              29623              30390
# 3       2009-02-22                067              43491               2762
# 4       2009-08-30                975                042               3051
# ...            ...                ...                ...                ...
# 558206         NaN                NaN               2163              V4575
# 558207         NaN                NaN              07041               5781
# 558208         NaN                NaN               V570              78079
# 558209         NaN                NaN                NaN                NaN
# 558210         NaN                NaN              78900              78609
#
#        ClmDiagnosisCode_3 ClmDiagnosisCode_4 ClmDiagnosisCode_5  \
# 0                    5853               7843               2768
# 1                   56400                NaN                NaN
# 2                   71690              34590              V1581
# 3                    7843              32723              V1041
# 4                   34400               5856              42732
# ...                   ...                ...                ...
# 558206              53190                NaN                NaN
# 558207              25000                NaN                NaN
# 558208                NaN                NaN                NaN
# 558209                NaN                NaN                NaN
# 558210               4280              71946               3310
#
#        ClmDiagnosisCode_6 ClmDiagnosisCode_7 ClmDiagnosisCode_8  \
# 0                   71590               2724              19889
# 1                     NaN                NaN                NaN
# 2                   32723                NaN                NaN
# 3                    4254              25062              40390
# 4                     486               5119              29620
# ...                   ...                ...                ...
# 558206                NaN                NaN                NaN
# 558207                NaN                NaN                NaN
# 558208                NaN                NaN                NaN
# 558209                NaN                NaN                NaN
# 558210              75311               2724               V103
#
#        ClmDiagnosisCode_9 ClmDiagnosisCode_10  ClmProcedureCode_1  \
# 0                    5849                 NaN                 NaN
# 1                     NaN                 NaN              7092.0
# 2                     NaN                 NaN                 NaN
# 3                    4019                 NaN               331.0
# 4                   20300                 NaN              3893.0
# ...                   ...                 ...                 ...
# 558206                NaN                 NaN                 NaN
# 558207                NaN                 NaN                 NaN
# 558208                NaN                 NaN                 NaN
# 558209                NaN                 NaN                 NaN
# 558210                NaN                 NaN                 NaN
#
#         ClmProcedureCode_2  ClmProcedureCode_3  ClmProcedureCode_4  \
# 0                      NaN                 NaN                 NaN
# 1                      NaN                 NaN                 NaN
# 2                      NaN                 NaN                 NaN
# 3                      NaN                 NaN                 NaN
# 4                      NaN                 NaN                 NaN
# ...                    ...                 ...                 ...
# 558206                 NaN                 NaN                 NaN
# 558207                 NaN                 NaN                 NaN
# 558208                 NaN                 NaN                 NaN
# 558209                 NaN                 NaN                 NaN
# 558210                 NaN                 NaN                 NaN
#
#         ClmProcedureCode_5  ClmProcedureCode_6 In/Out
# 0                      NaN                 NaN     In
# 1                      NaN                 NaN     In
# 2                      NaN                 NaN     In
# 3                      NaN                 NaN     In
# 4                      NaN                 NaN     In
# ...                    ...                 ...    ...
# 558206                 NaN                 NaN    Out
# 558207                 NaN                 NaN    Out
# 558208                 NaN                 NaN    Out
# 558209                 NaN                 NaN    Out
# 558210                 NaN                 NaN    Out
#
# [558211 rows x 31 columns]

# %% [markdown]
# # Merging patients with claims
#
# Using the beneficiary column in the claim data, we can also populate details about the patient in each of the transactions.
#
# This potentially allows us to engineer some additional features that are specific to beneficiaries across transactions. For example, how long has it been since a beneficiary's last claim?

# %%
# Do a left outer join in case there are any claims that don't have any corresponding beneficiaries
# defined in the beneficiary data set
train_claims = train_claims.merge(train_beneficiary, how='left', on='BeneID')
train_claims
# Out:
#             BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0        BENE11001   CLM46614   2009-04-12  2009-04-18  PRV55912
# 1        BENE11001   CLM66048   2009-08-31  2009-09-02  PRV55907
# 2        BENE11001   CLM68358   2009-09-17  2009-09-20  PRV56046
# 3        BENE11011   CLM38412   2009-02-14  2009-02-22  PRV52405
# 4        BENE11014   CLM63689   2009-08-13  2009-08-30  PRV56614
# ...            ...        ...          ...         ...       ...
# 558206  BENE159198  CLM510792   2009-08-06  2009-08-06  PRV53699
# 558207  BENE159198  CLM551294   2009-08-29  2009-08-29  PRV53702
# 558208  BENE159198  CLM596444   2009-09-24  2009-09-24  PRV53676
# 558209  BENE159198  CLM636992   2009-10-18  2009-10-18  PRV53689
# 558210  BENE159198  CLM686139   2009-11-17  2009-11-18  PRV53689
#
#         InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                        26000          PHY390922                NaN
# 1                         5000          PHY318495          PHY318495
# 2                         5000          PHY372395                NaN
# 3                         5000          PHY369659          PHY392961
# 4                        10000          PHY379376          PHY398258
# ...                        ...                ...                ...
# 558206                     800          PHY364188          PHY364188
# 558207                     400          PHY423019          PHY332284
# 558208                      60          PHY361063                NaN
# 558209                      70          PHY403198                NaN
# 558210                      80          PHY419379                NaN
#
#        OtherPhysician AdmissionDt ClmAdmitDiagnosisCode  DeductibleAmtPaid  \
# 0                 NaN  2009-04-12                  7866             1068.0
# 1                 NaN  2009-08-31                  6186             1068.0
# 2           PHY324689  2009-09-17                 29590             1068.0
# 3           PHY349768  2009-02-14                   431             1068.0
# 4                 NaN  2009-08-13                 78321             1068.0
# ...               ...         ...                   ...                ...
# 558206      PHY385752         NaN                   NaN                0.0
# 558207            NaN         NaN                   NaN                0.0
# 558208            NaN         NaN                   NaN                0.0
# 558209      PHY419379         NaN                   NaN                0.0
# 558210      PHY419379         NaN                   NaN                0.0
#
#        DischargeDt DiagnosisGroupCode ClmDiagnosisCode_1 ClmDiagnosisCode_2  \
# 0       2009-04-18                201               1970               4019
# 1       2009-09-02                750               6186               2948
# 2       2009-09-20                883              29623              30390
# 3       2009-02-22                067              43491               2762
# 4       2009-08-30                975                042               3051
# ...            ...                ...                ...                ...
# 558206         NaN                NaN               2163              V4575
# 558207         NaN                NaN              07041               5781
# 558208         NaN                NaN               V570              78079
# 558209         NaN                NaN                NaN                NaN
# 558210         NaN                NaN              78900              78609
#
#        ClmDiagnosisCode_3 ClmDiagnosisCode_4 ClmDiagnosisCode_5  \
# 0                    5853               7843               2768
# 1                   56400                NaN                NaN
# 2                   71690              34590              V1581
# 3                    7843              32723              V1041
# 4                   34400               5856              42732
# ...                   ...                ...                ...
# 558206              53190                NaN                NaN
# 558207              25000                NaN                NaN
# 558208                NaN                NaN                NaN
# 558209                NaN                NaN                NaN
# 558210               4280              71946               3310
#
#        ClmDiagnosisCode_6 ClmDiagnosisCode_7 ClmDiagnosisCode_8  \
# 0                   71590               2724              19889
# 1                     NaN                NaN                NaN
# 2                   32723                NaN                NaN
# 3                    4254              25062              40390
# 4                     486               5119              29620
# ...                   ...                ...                ...
# 558206                NaN                NaN                NaN
# 558207                NaN                NaN                NaN
# 558208                NaN                NaN                NaN
# 558209                NaN                NaN                NaN
# 558210              75311               2724               V103
#
#        ClmDiagnosisCode_9 ClmDiagnosisCode_10  ClmProcedureCode_1  \
# 0                    5849                 NaN                 NaN
# 1                     NaN                 NaN              7092.0
# 2                     NaN                 NaN                 NaN
# 3                    4019                 NaN               331.0
# 4                   20300                 NaN              3893.0
# ...                   ...                 ...                 ...
# 558206                NaN                 NaN                 NaN
# 558207                NaN                 NaN                 NaN
# 558208                NaN                 NaN                 NaN
# 558209                NaN                 NaN                 NaN
# 558210                NaN                 NaN                 NaN
#
#         ClmProcedureCode_2  ClmProcedureCode_3  ClmProcedureCode_4  \
# 0                      NaN                 NaN                 NaN
# 1                      NaN                 NaN                 NaN
# 2                      NaN                 NaN                 NaN
# 3                      NaN                 NaN                 NaN
# 4                      NaN                 NaN                 NaN
# ...                    ...                 ...                 ...
# 558206                 NaN                 NaN                 NaN
# 558207                 NaN                 NaN                 NaN
# 558208                 NaN                 NaN                 NaN
# 558209                 NaN                 NaN                 NaN
# 558210                 NaN                 NaN                 NaN
#
#         ClmProcedureCode_5  ClmProcedureCode_6 In/Out         DOB  DOD  \
# 0                      NaN                 NaN     In  1943-01-01  NaN
# 1                      NaN                 NaN     In  1943-01-01  NaN
# 2                      NaN                 NaN     In  1943-01-01  NaN
# 3                      NaN                 NaN     In  1914-03-01  NaN
# 4                      NaN                 NaN     In  1938-04-01  NaN
# ...                    ...                 ...    ...         ...  ...
# 558206                 NaN                 NaN    Out  1952-04-01  NaN
# 558207                 NaN                 NaN    Out  1952-04-01  NaN
# 558208                 NaN                 NaN    Out  1952-04-01  NaN
# 558209                 NaN                 NaN    Out  1952-04-01  NaN
# 558210                 NaN                 NaN    Out  1952-04-01  NaN
#
#         Gender  Race RenalDiseaseIndicator  State  County  \
# 0            1     1                     0     39     230
# 1            1     1                     0     39     230
# 2            1     1                     0     39     230
# 3            2     2                     0      1     360
# 4            2     1                     Y     45     780
# ...        ...   ...                   ...    ...     ...
# 558206       2     1                     0     21      20
# 558207       2     1                     0     21      20
# 558208       2     1                     0     21      20
# 558209       2     1                     0     21      20
# 558210       2     1                     0     21      20
#
#         NoOfMonths_PartACov  NoOfMonths_PartBCov  ChronicCond_Alzheimer  \
# 0                        12                   12                      1
# 1                        12                   12                      1
# 2                        12                   12                      1
# 3                        12                   12                      2
# 4                        12                   12                      2
# ...                     ...                  ...                    ...
# 558206                   12                   12                      1
# 558207                   12                   12                      1
# 558208                   12                   12                      1
# 558209                   12                   12                      1
# 558210                   12                   12                      1
#
#         ChronicCond_Heartfailure  ChronicCond_KidneyDisease  \
# 0                              2                          1
# 1                              2                          1
# 2                              2                          1
# 3                              1                          1
# 4                              1                          1
# ...                          ...                        ...
# 558206                         1                          2
# 558207                         1                          2
# 558208                         1                          2
# 558209                         1                          2
# 558210                         1                          2
#
#         ChronicCond_Cancer  ChronicCond_ObstrPulmonary  \
# 0                        2                           2
# 1                        2                           2
# 2                        2                           2
# 3                        2                           2
# 4                        2                           1
# ...                    ...                         ...
# 558206                   2                           2
# 558207                   2                           2
# 558208                   2                           2
# 558209                   2                           2
# 558210                   2                           2
#
#         ChronicCond_Depression  ChronicCond_Diabetes  \
# 0                            1                     1
# 1                            1                     1
# 2                            1                     1
# 3                            1                     1
# 4                            1                     2
# ...                        ...                   ...
# 558206                       1                     1
# 558207                       1                     1
# 558208                       1                     1
# 558209                       1                     1
# 558210                       1                     1
#
#         ChronicCond_IschemicHeart  ChronicCond_Osteoporasis  \
# 0                               1                         2
# 1                               1                         2
# 2                               1                         2
# 3                               2                         2
# 4                               1                         2
# ...                           ...                       ...
# 558206                          2                         2
# 558207                          2                         2
# 558208                          2                         2
# 558209                          2                         2
# 558210                          2                         2
#
#         ChronicCond_rheumatoidarthritis  ChronicCond_stroke  \
# 0                                     1                   1
# 1                                     1                   1
# 2                                     1                   1
# 3                                     1                   1
# 4                                     2                   2
# ...                                 ...                 ...
# 558206                                1                   2
# 558207                                1                   2
# 558208                                1                   2
# 558209                                1                   2
# 558210                                1                   2
#
#         IPAnnualReimbursementAmt  IPAnnualDeductibleAmt  \
# 0                          36000                   3204
# 1                          36000                   3204
# 2                          36000                   3204
# 3                           5000                   1068
# 4                          21260                   2136
# ...                          ...                    ...
# 558206                         0                      0
# 558207                         0                      0
# 558208                         0                      0
# 558209                         0                      0
# 558210                         0                      0
#
#         OPAnnualReimbursementAmt  OPAnnualDeductibleAmt
# 0                             60                     70
# 1                             60                     70
# 2                             60                     70
# 3                            250                    320
# 4                            120                    100
# ...                          ...                    ...
# 558206                      5470                   1870
# 558207                      5470                   1870
# 558208                      5470                   1870
# 558209                      5470                   1870
# 558210                      5470                   1870
#
# [558211 rows x 55 columns]

# %% [markdown]
# # Cleaning data
#
# There are some fields that have empty data. We need a way to properly deal with those fields so that analysis can be performed.
#
# It's probably too early to throw data out, so instead give these fields a friendly value like "None" and we can revisit whether we can throw them out entirely later.
#
# ## Cleanup in the next cell:
# - In/Out column - Changed to boolean value, where 0 -> outpatient, 1-> inpatient
# - (*)Physician columns - Remove PHY prefix from provider IDs

# %%
# Use apply() to map columns to new values that have been sanitized (i.e., transform from strings into numeric)
train_claims['In/Out'] = train_claims['In/Out'].apply(lambda x: 1 if x == 'In' else 0)

# The next few transforms require checks using pandas.isnull() to prevent errors for empty cells
train_claims['AttendingPhysician'] = train_claims['AttendingPhysician'].apply(lambda ap: ap.split('PHY')[-1] if not pd.isnull(ap) else ap)
train_claims['OperatingPhysician'] = train_claims['OperatingPhysician'].apply(lambda op: op.split('PHY')[-1] if not pd.isnull(op) else op)
train_claims['OtherPhysician'] = train_claims['OtherPhysician'].apply(lambda op: op.split('PHY')[-1] if not pd.isnull(op) else op)

train_claims
# Out:
#             BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0        BENE11001   CLM46614   2009-04-12  2009-04-18  PRV55912
# 1        BENE11001   CLM66048   2009-08-31  2009-09-02  PRV55907
# 2        BENE11001   CLM68358   2009-09-17  2009-09-20  PRV56046
# 3        BENE11011   CLM38412   2009-02-14  2009-02-22  PRV52405
# 4        BENE11014   CLM63689   2009-08-13  2009-08-30  PRV56614
# ...            ...        ...          ...         ...       ...
# 558206  BENE159198  CLM510792   2009-08-06  2009-08-06  PRV53699
# 558207  BENE159198  CLM551294   2009-08-29  2009-08-29  PRV53702
# 558208  BENE159198  CLM596444   2009-09-24  2009-09-24  PRV53676
# 558209  BENE159198  CLM636992   2009-10-18  2009-10-18  PRV53689
# 558210  BENE159198  CLM686139   2009-11-17  2009-11-18  PRV53689
#
#         InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                        26000             390922                NaN
# 1                         5000             318495             318495
# 2                         5000             372395                NaN
# 3                         5000             369659             392961
# 4                        10000             379376             398258
# ...                        ...                ...                ...
# 558206                     800             364188             364188
# 558207                     400             423019             332284
# 558208                      60             361063                NaN
# 558209                      70             403198                NaN
# 558210                      80             419379                NaN
#
#        OtherPhysician AdmissionDt ClmAdmitDiagnosisCode  DeductibleAmtPaid  \
# 0                 NaN  2009-04-12                  7866             1068.0
# 1                 NaN  2009-08-31                  6186             1068.0
# 2              324689  2009-09-17                 29590             1068.0
# 3              349768  2009-02-14                   431             1068.0
# 4                 NaN  2009-08-13                 78321             1068.0
# ...               ...         ...                   ...                ...
# 558206         385752         NaN                   NaN                0.0
# 558207            NaN         NaN                   NaN                0.0
# 558208            NaN         NaN                   NaN                0.0
# 558209         419379         NaN                   NaN                0.0
# 558210         419379         NaN                   NaN                0.0
#
#        DischargeDt DiagnosisGroupCode ClmDiagnosisCode_1 ClmDiagnosisCode_2  \
# 0       2009-04-18                201               1970               4019
# 1       2009-09-02                750               6186               2948
# 2       2009-09-20                883              29623              30390
# 3       2009-02-22                067              43491               2762
# 4       2009-08-30                975                042               3051
# ...            ...                ...                ...                ...
# 558206         NaN                NaN               2163              V4575
# 558207         NaN                NaN              07041               5781
# 558208         NaN                NaN               V570              78079
# 558209         NaN                NaN                NaN                NaN
# 558210         NaN                NaN              78900              78609
#
#        ClmDiagnosisCode_3 ClmDiagnosisCode_4 ClmDiagnosisCode_5  \
# 0                    5853               7843               2768
# 1                   56400                NaN                NaN
# 2                   71690              34590              V1581
# 3                    7843              32723              V1041
# 4                   34400               5856              42732
# ...                   ...                ...                ...
# 558206              53190                NaN                NaN
# 558207              25000                NaN                NaN
# 558208                NaN                NaN                NaN
# 558209                NaN                NaN                NaN
# 558210               4280              71946               3310
#
#        ClmDiagnosisCode_6 ClmDiagnosisCode_7 ClmDiagnosisCode_8  \
# 0                   71590               2724              19889
# 1                     NaN                NaN                NaN
# 2                   32723                NaN                NaN
# 3                    4254              25062              40390
# 4                     486               5119              29620
# ...                   ...                ...                ...
# 558206                NaN                NaN                NaN
# 558207                NaN                NaN                NaN
# 558208                NaN                NaN                NaN
# 558209                NaN                NaN                NaN
# 558210              75311               2724               V103
#
#        ClmDiagnosisCode_9 ClmDiagnosisCode_10  ClmProcedureCode_1  \
# 0                    5849                 NaN                 NaN
# 1                     NaN                 NaN              7092.0
# 2                     NaN                 NaN                 NaN
# 3                    4019                 NaN               331.0
# 4                   20300                 NaN              3893.0
# ...                   ...                 ...                 ...
# 558206                NaN                 NaN                 NaN
# 558207                NaN                 NaN                 NaN
# 558208                NaN                 NaN                 NaN
# 558209                NaN                 NaN                 NaN
# 558210                NaN                 NaN                 NaN
#
#         ClmProcedureCode_2  ClmProcedureCode_3  ClmProcedureCode_4  \
# 0                      NaN                 NaN                 NaN
# 1                      NaN                 NaN                 NaN
# 2                      NaN                 NaN                 NaN
# 3                      NaN                 NaN                 NaN
# 4                      NaN                 NaN                 NaN
# ...                    ...                 ...                 ...
# 558206                 NaN                 NaN                 NaN
# 558207                 NaN                 NaN                 NaN
# 558208                 NaN                 NaN                 NaN
# 558209                 NaN                 NaN                 NaN
# 558210                 NaN                 NaN                 NaN
#
#         ClmProcedureCode_5  ClmProcedureCode_6  In/Out         DOB  DOD  \
# 0                      NaN                 NaN       1  1943-01-01  NaN
# 1                      NaN                 NaN       1  1943-01-01  NaN
# 2                      NaN                 NaN       1  1943-01-01  NaN
# 3                      NaN                 NaN       1  1914-03-01  NaN
# 4                      NaN                 NaN       1  1938-04-01  NaN
# ...                    ...                 ...     ...         ...  ...
# 558206                 NaN                 NaN       0  1952-04-01  NaN
# 558207                 NaN                 NaN       0  1952-04-01  NaN
# 558208                 NaN                 NaN       0  1952-04-01  NaN
# 558209                 NaN                 NaN       0  1952-04-01  NaN
# 558210                 NaN                 NaN       0  1952-04-01  NaN
#
#         Gender  Race RenalDiseaseIndicator  State  County  \
# 0            1     1                     0     39     230
# 1            1     1                     0     39     230
# 2            1     1                     0     39     230
# 3            2     2                     0      1     360
# 4            2     1                     Y     45     780
# ...        ...   ...                   ...    ...     ...
# 558206       2     1                     0     21      20
# 558207       2     1                     0     21      20
# 558208       2     1                     0     21      20
# 558209       2     1                     0     21      20
# 558210       2     1                     0     21      20
#
#         NoOfMonths_PartACov  NoOfMonths_PartBCov  ChronicCond_Alzheimer  \
# 0                        12                   12                      1
# 1                        12                   12                      1
# 2                        12                   12                      1
# 3                        12                   12                      2
# 4                        12                   12                      2
# ...                     ...                  ...                    ...
# 558206                   12                   12                      1
# 558207                   12                   12                      1
# 558208                   12                   12                      1
# 558209                   12                   12                      1
# 558210                   12                   12                      1
#
#         ChronicCond_Heartfailure  ChronicCond_KidneyDisease  \
# 0                              2                          1
# 1                              2                          1
# 2                              2                          1
# 3                              1                          1
# 4                              1                          1
# ...                          ...                        ...
# 558206                         1                          2
# 558207                         1                          2
# 558208                         1                          2
# 558209                         1                          2
# 558210                         1                          2
#
#         ChronicCond_Cancer  ChronicCond_ObstrPulmonary  \
# 0                        2                           2
# 1                        2                           2
# 2                        2                           2
# 3                        2                           2
# 4                        2                           1
# ...                    ...                         ...
# 558206                   2                           2
# 558207                   2                           2
# 558208                   2                           2
# 558209                   2                           2
# 558210                   2                           2
#
#         ChronicCond_Depression  ChronicCond_Diabetes  \
# 0                            1                     1
# 1                            1                     1
# 2                            1                     1
# 3                            1                     1
# 4                            1                     2
# ...                        ...                   ...
# 558206                       1                     1
# 558207                       1                     1
# 558208                       1                     1
# 558209                       1                     1
# 558210                       1                     1
#
#         ChronicCond_IschemicHeart  ChronicCond_Osteoporasis  \
# 0                               1                         2
# 1                               1                         2
# 2                               1                         2
# 3                               2                         2
# 4                               1                         2
# ...                           ...                       ...
# 558206                          2                         2
# 558207                          2                         2
# 558208                          2                         2
# 558209                          2                         2
# 558210                          2                         2
#
#         ChronicCond_rheumatoidarthritis  ChronicCond_stroke  \
# 0                                     1                   1
# 1                                     1                   1
# 2                                     1                   1
# 3                                     1                   1
# 4                                     2                   2
# ...                                 ...                 ...
# 558206                                1                   2
# 558207                                1                   2
# 558208                                1                   2
# 558209                                1                   2
# 558210                                1                   2
#
#         IPAnnualReimbursementAmt  IPAnnualDeductibleAmt  \
# 0                          36000                   3204
# 1                          36000                   3204
# 2                          36000                   3204
# 3                           5000                   1068
# 4                          21260                   2136
# ...                          ...                    ...
# 558206                         0                      0
# 558207                         0                      0
# 558208                         0                      0
# 558209                         0                      0
# 558210                         0                      0
#
#         OPAnnualReimbursementAmt  OPAnnualDeductibleAmt
# 0                             60                     70
# 1                             60                     70
# 2                             60                     70
# 3                            250                    320
# 4                            120                    100
# ...                          ...                    ...
# 558206                      5470                   1870
# 558207                      5470                   1870
# 558208                      5470                   1870
# 558209                      5470                   1870
# 558210                      5470                   1870
#
# [558211 rows x 55 columns]

# %% [markdown]
# ## Cleanup in the next cell:
# - Some of the diagnosis code values are prefixed with a character. Remove them to make values numeric.
#
# > **TODO: Decide whether we need to get all fancy pants and save off the various character flags
#           that appear alongside the charge codes. Looks like 'E' and 'V' are the ones that show
#           up most, but maybe there are others?**
#
# > **TODO: Some resources online recommend using one-hot encoding to represent categorical data for decision tree algorithms:
# https://stackoverflow.com/questions/38108832/passing-categorical-data-to-sklearn-decision-tree
# Answer suggests one-hot is not super performant, but that might be acceptable since this data set isn't enormous...**

# %%
# Build list of diagnosis code columns
diagnosis_code_cols = [f'ClmDiagnosisCode_{x+1}' for x in range(10)]

# Strip ASCII characters from all of the claim diagnosis codes.
import string
for col in diagnosis_code_cols:
    train_claims[col] = train_claims[col].apply(lambda c: c.strip(string.ascii_letters) if not pd.isnull(c) else c)

# Check that all of the claim codes are now integers
assert sum([len([x for x in train_claims[col] if not pd.isnull(x) and not str(x).isdigit()]) for col in diagnosis_code_cols]) == 0

train_claims
# Out:
#             BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0        BENE11001   CLM46614   2009-04-12  2009-04-18  PRV55912
# 1        BENE11001   CLM66048   2009-08-31  2009-09-02  PRV55907
# 2        BENE11001   CLM68358   2009-09-17  2009-09-20  PRV56046
# 3        BENE11011   CLM38412   2009-02-14  2009-02-22  PRV52405
# 4        BENE11014   CLM63689   2009-08-13  2009-08-30  PRV56614
# ...            ...        ...          ...         ...       ...
# 558206  BENE159198  CLM510792   2009-08-06  2009-08-06  PRV53699
# 558207  BENE159198  CLM551294   2009-08-29  2009-08-29  PRV53702
# 558208  BENE159198  CLM596444   2009-09-24  2009-09-24  PRV53676
# 558209  BENE159198  CLM636992   2009-10-18  2009-10-18  PRV53689
# 558210  BENE159198  CLM686139   2009-11-17  2009-11-18  PRV53689
#
#         InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                        26000             390922                NaN
# 1                         5000             318495             318495
# 2                         5000             372395                NaN
# 3                         5000             369659             392961
# 4                        10000             379376             398258
# ...                        ...                ...                ...
# 558206                     800             364188             364188
# 558207                     400             423019             332284
# 558208                      60             361063                NaN
# 558209                      70             403198                NaN
# 558210                      80             419379                NaN
#
#        OtherPhysician AdmissionDt ClmAdmitDiagnosisCode  DeductibleAmtPaid  \
# 0                 NaN  2009-04-12                  7866             1068.0
# 1                 NaN  2009-08-31                  6186             1068.0
# 2              324689  2009-09-17                 29590             1068.0
# 3              349768  2009-02-14                   431             1068.0
# 4                 NaN  2009-08-13                 78321             1068.0
# ...               ...         ...                   ...                ...
# 558206         385752         NaN                   NaN                0.0
# 558207            NaN         NaN                   NaN                0.0
# 558208            NaN         NaN                   NaN                0.0
# 558209         419379         NaN                   NaN                0.0
# 558210         419379         NaN                   NaN                0.0
#
#        DischargeDt DiagnosisGroupCode ClmDiagnosisCode_1 ClmDiagnosisCode_2  \
# 0       2009-04-18                201               1970               4019
# 1       2009-09-02                750               6186               2948
# 2       2009-09-20                883              29623              30390
# 3       2009-02-22                067              43491               2762
# 4       2009-08-30                975                042               3051
# ...            ...                ...                ...                ...
# 558206         NaN                NaN               2163               4575
# 558207         NaN                NaN              07041               5781
# 558208         NaN                NaN                570              78079
# 558209         NaN                NaN                NaN                NaN
# 558210         NaN                NaN              78900              78609
#
#        ClmDiagnosisCode_3 ClmDiagnosisCode_4 ClmDiagnosisCode_5  \
# 0                    5853               7843               2768
# 1                   56400                NaN                NaN
# 2                   71690              34590               1581
# 3                    7843              32723               1041
# 4                   34400               5856              42732
# ...                   ...                ...                ...
# 558206              53190                NaN                NaN
# 558207              25000                NaN                NaN
# 558208                NaN                NaN                NaN
# 558209                NaN                NaN                NaN
# 558210               4280              71946               3310
#
#        ClmDiagnosisCode_6 ClmDiagnosisCode_7 ClmDiagnosisCode_8  \
# 0                   71590               2724              19889
# 1                     NaN                NaN                NaN
# 2                   32723                NaN                NaN
# 3                    4254              25062              40390
# 4                     486               5119              29620
# ...                   ...                ...                ...
# 558206                NaN                NaN                NaN
# 558207                NaN                NaN                NaN
# 558208                NaN                NaN                NaN
# 558209                NaN                NaN                NaN
# 558210              75311               2724                103
#
#        ClmDiagnosisCode_9 ClmDiagnosisCode_10  ClmProcedureCode_1  \
# 0                    5849                 NaN                 NaN
# 1                     NaN                 NaN              7092.0
# 2                     NaN                 NaN                 NaN
# 3                    4019                 NaN               331.0
# 4                   20300                 NaN              3893.0
# ...                   ...                 ...                 ...
# 558206                NaN                 NaN                 NaN
# 558207                NaN                 NaN                 NaN
# 558208                NaN                 NaN                 NaN
# 558209                NaN                 NaN                 NaN
# 558210                NaN                 NaN                 NaN
#
#         ClmProcedureCode_2  ClmProcedureCode_3  ClmProcedureCode_4  \
# 0                      NaN                 NaN                 NaN
# 1                      NaN                 NaN                 NaN
# 2                      NaN                 NaN                 NaN
# 3                      NaN                 NaN                 NaN
# 4                      NaN                 NaN                 NaN
# ...                    ...                 ...                 ...
# 558206                 NaN                 NaN                 NaN
# 558207                 NaN                 NaN                 NaN
# 558208                 NaN                 NaN                 NaN
# 558209                 NaN                 NaN                 NaN
# 558210                 NaN                 NaN                 NaN
#
#         ClmProcedureCode_5  ClmProcedureCode_6  In/Out         DOB  DOD  \
# 0                      NaN                 NaN       1  1943-01-01  NaN
# 1                      NaN                 NaN       1  1943-01-01  NaN
# 2                      NaN                 NaN       1  1943-01-01  NaN
# 3                      NaN                 NaN       1  1914-03-01  NaN
# 4                      NaN                 NaN       1  1938-04-01  NaN
# ...                    ...                 ...     ...         ...  ...
# 558206                 NaN                 NaN       0  1952-04-01  NaN
# 558207                 NaN                 NaN       0  1952-04-01  NaN
# 558208                 NaN                 NaN       0  1952-04-01  NaN
# 558209                 NaN                 NaN       0  1952-04-01  NaN
# 558210                 NaN                 NaN       0  1952-04-01  NaN
#
#         Gender  Race RenalDiseaseIndicator  State  County  \
# 0            1     1                     0     39     230
# 1            1     1                     0     39     230
# 2            1     1                     0     39     230
# 3            2     2                     0      1     360
# 4            2     1                     Y     45     780
# ...        ...   ...                   ...    ...     ...
# 558206       2     1                     0     21      20
# 558207       2     1                     0     21      20
# 558208       2     1                     0     21      20
# 558209       2     1                     0     21      20
# 558210       2     1                     0     21      20
#
#         NoOfMonths_PartACov  NoOfMonths_PartBCov  ChronicCond_Alzheimer  \
# 0                        12                   12                      1
# 1                        12                   12                      1
# 2                        12                   12                      1
# 3                        12                   12                      2
# 4                        12                   12                      2
# ...                     ...                  ...                    ...
# 558206                   12                   12                      1
# 558207                   12                   12                      1
# 558208                   12                   12                      1
# 558209                   12                   12                      1
# 558210                   12                   12                      1
#
#         ChronicCond_Heartfailure  ChronicCond_KidneyDisease  \
# 0                              2                          1
# 1                              2                          1
# 2                              2                          1
# 3                              1                          1
# 4                              1                          1
# ...                          ...                        ...
# 558206                         1                          2
# 558207                         1                          2
# 558208                         1                          2
# 558209                         1                          2
# 558210                         1                          2
#
#         ChronicCond_Cancer  ChronicCond_ObstrPulmonary  \
# 0                        2                           2
# 1                        2                           2
# 2                        2                           2
# 3                        2                           2
# 4                        2                           1
# ...                    ...                         ...
# 558206                   2                           2
# 558207                   2                           2
# 558208                   2                           2
# 558209                   2                           2
# 558210                   2                           2
#
#         ChronicCond_Depression  ChronicCond_Diabetes  \
# 0                            1                     1
# 1                            1                     1
# 2                            1                     1
# 3                            1                     1
# 4                            1                     2
# ...                        ...                   ...
# 558206                       1                     1
# 558207                       1                     1
# 558208                       1                     1
# 558209                       1                     1
# 558210                       1                     1
#
#         ChronicCond_IschemicHeart  ChronicCond_Osteoporasis  \
# 0                               1                         2
# 1                               1                         2
# 2                               1                         2
# 3                               2                         2
# 4                               1                         2
# ...                           ...                       ...
# 558206                          2                         2
# 558207                          2                         2
# 558208                          2                         2
# 558209                          2                         2
# 558210                          2                         2
#
#         ChronicCond_rheumatoidarthritis  ChronicCond_stroke  \
# 0                                     1                   1
# 1                                     1                   1
# 2                                     1                   1
# 3                                     1                   1
# 4                                     2                   2
# ...                                 ...                 ...
# 558206                                1                   2
# 558207                                1                   2
# 558208                                1                   2
# 558209                                1                   2
# 558210                                1                   2
#
#         IPAnnualReimbursementAmt  IPAnnualDeductibleAmt  \
# 0                          36000                   3204
# 1                          36000                   3204
# 2                          36000                   3204
# 3                           5000                   1068
# 4                          21260                   2136
# ...                          ...                    ...
# 558206                         0                      0
# 558207                         0                      0
# 558208                         0                      0
# 558209                         0                      0
# 558210                         0                      0
#
#         OPAnnualReimbursementAmt  OPAnnualDeductibleAmt
# 0                             60                     70
# 1                             60                     70
# 2                             60                     70
# 3                            250                    320
# 4                            120                    100
# ...                          ...                    ...
# 558206                      5470                   1870
# 558207                      5470                   1870
# 558208                      5470                   1870
# 558209                      5470                   1870
# 558210                      5470                   1870
#
# [558211 rows x 55 columns]

# %% [markdown]
# # Cleanup in the next cell:
#
# Some of the deductible information has NaN. For now, set these values to 0.
#
# > TODO: Is setting to 0 the right approach?

# %%
# Set NaN values, for deductible information, to 0  
train_claims['DeductibleAmtPaid'] = train_claims['DeductibleAmtPaid'].apply(lambda amt: 0 if pd.isnull(amt) else amt)

train_claims
# Out:
#             BeneID    ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0        BENE11001   CLM46614   2009-04-12  2009-04-18  PRV55912
# 1        BENE11001   CLM66048   2009-08-31  2009-09-02  PRV55907
# 2        BENE11001   CLM68358   2009-09-17  2009-09-20  PRV56046
# 3        BENE11011   CLM38412   2009-02-14  2009-02-22  PRV52405
# 4        BENE11014   CLM63689   2009-08-13  2009-08-30  PRV56614
# ...            ...        ...          ...         ...       ...
# 558206  BENE159198  CLM510792   2009-08-06  2009-08-06  PRV53699
# 558207  BENE159198  CLM551294   2009-08-29  2009-08-29  PRV53702
# 558208  BENE159198  CLM596444   2009-09-24  2009-09-24  PRV53676
# 558209  BENE159198  CLM636992   2009-10-18  2009-10-18  PRV53689
# 558210  BENE159198  CLM686139   2009-11-17  2009-11-18  PRV53689
#
#         InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                        26000             390922                NaN
# 1                         5000             318495             318495
# 2                         5000             372395                NaN
# 3                         5000             369659             392961
# 4                        10000             379376             398258
# ...                        ...                ...                ...
# 558206                     800             364188             364188
# 558207                     400             423019             332284
# 558208                      60             361063                NaN
# 558209                      70             403198                NaN
# 558210                      80             419379                NaN
#
#        OtherPhysician AdmissionDt ClmAdmitDiagnosisCode  DeductibleAmtPaid  \
# 0                 NaN  2009-04-12                  7866             1068.0
# 1                 NaN  2009-08-31                  6186             1068.0
# 2              324689  2009-09-17                 29590             1068.0
# 3              349768  2009-02-14                   431             1068.0
# 4                 NaN  2009-08-13                 78321             1068.0
# ...               ...         ...                   ...                ...
# 558206         385752         NaN                   NaN                0.0
# 558207            NaN         NaN                   NaN                0.0
# 558208            NaN         NaN                   NaN                0.0
# 558209         419379         NaN                   NaN                0.0
# 558210         419379         NaN                   NaN                0.0
#
#        DischargeDt DiagnosisGroupCode ClmDiagnosisCode_1 ClmDiagnosisCode_2  \
# 0       2009-04-18                201               1970               4019
# 1       2009-09-02                750               6186               2948
# 2       2009-09-20                883              29623              30390
# 3       2009-02-22                067              43491               2762
# 4       2009-08-30                975                042               3051
# ...            ...                ...                ...                ...
# 558206         NaN                NaN               2163               4575
# 558207         NaN                NaN              07041               5781
# 558208         NaN                NaN                570              78079
# 558209         NaN                NaN                NaN                NaN
# 558210         NaN                NaN              78900              78609
#
#        ClmDiagnosisCode_3 ClmDiagnosisCode_4 ClmDiagnosisCode_5  \
# 0                    5853               7843               2768
# 1                   56400                NaN                NaN
# 2                   71690              34590               1581
# 3                    7843              32723               1041
# 4                   34400               5856              42732
# ...                   ...                ...                ...
# 558206              53190                NaN                NaN
# 558207              25000                NaN                NaN
# 558208                NaN                NaN                NaN
# 558209                NaN                NaN                NaN
# 558210               4280              71946               3310
#
#        ClmDiagnosisCode_6 ClmDiagnosisCode_7 ClmDiagnosisCode_8  \
# 0                   71590               2724              19889
# 1                     NaN                NaN                NaN
# 2                   32723                NaN                NaN
# 3                    4254              25062              40390
# 4                     486               5119              29620
# ...                   ...                ...                ...
# 558206                NaN                NaN                NaN
# 558207                NaN                NaN                NaN
# 558208                NaN                NaN                NaN
# 558209                NaN                NaN                NaN
# 558210              75311               2724                103
#
#        ClmDiagnosisCode_9 ClmDiagnosisCode_10  ClmProcedureCode_1  \
# 0                    5849                 NaN                 NaN
# 1                     NaN                 NaN              7092.0
# 2                     NaN                 NaN                 NaN
# 3                    4019                 NaN               331.0
# 4                   20300                 NaN              3893.0
# ...                   ...                 ...                 ...
# 558206                NaN                 NaN                 NaN
# 558207                NaN                 NaN                 NaN
# 558208                NaN                 NaN                 NaN
# 558209                NaN                 NaN                 NaN
# 558210                NaN                 NaN                 NaN
#
#         ClmProcedureCode_2  ClmProcedureCode_3  ClmProcedureCode_4  \
# 0                      NaN                 NaN                 NaN
# 1                      NaN                 NaN                 NaN
# 2                      NaN                 NaN                 NaN
# 3                      NaN                 NaN                 NaN
# 4                      NaN                 NaN                 NaN
# ...                    ...                 ...                 ...
# 558206                 NaN                 NaN                 NaN
# 558207                 NaN                 NaN                 NaN
# 558208                 NaN                 NaN                 NaN
# 558209                 NaN                 NaN                 NaN
# 558210                 NaN                 NaN                 NaN
#
#         ClmProcedureCode_5  ClmProcedureCode_6  In/Out         DOB  DOD  \
# 0                      NaN                 NaN       1  1943-01-01  NaN
# 1                      NaN                 NaN       1  1943-01-01  NaN
# 2                      NaN                 NaN       1  1943-01-01  NaN
# 3                      NaN                 NaN       1  1914-03-01  NaN
# 4                      NaN                 NaN       1  1938-04-01  NaN
# ...                    ...                 ...     ...         ...  ...
# 558206                 NaN                 NaN       0  1952-04-01  NaN
# 558207                 NaN                 NaN       0  1952-04-01  NaN
# 558208                 NaN                 NaN       0  1952-04-01  NaN
# 558209                 NaN                 NaN       0  1952-04-01  NaN
# 558210                 NaN                 NaN       0  1952-04-01  NaN
#
#         Gender  Race RenalDiseaseIndicator  State  County  \
# 0            1     1                     0     39     230
# 1            1     1                     0     39     230
# 2            1     1                     0     39     230
# 3            2     2                     0      1     360
# 4            2     1                     Y     45     780
# ...        ...   ...                   ...    ...     ...
# 558206       2     1                     0     21      20
# 558207       2     1                     0     21      20
# 558208       2     1                     0     21      20
# 558209       2     1                     0     21      20
# 558210       2     1                     0     21      20
#
#         NoOfMonths_PartACov  NoOfMonths_PartBCov  ChronicCond_Alzheimer  \
# 0                        12                   12                      1
# 1                        12                   12                      1
# 2                        12                   12                      1
# 3                        12                   12                      2
# 4                        12                   12                      2
# ...                     ...                  ...                    ...
# 558206                   12                   12                      1
# 558207                   12                   12                      1
# 558208                   12                   12                      1
# 558209                   12                   12                      1
# 558210                   12                   12                      1
#
#         ChronicCond_Heartfailure  ChronicCond_KidneyDisease  \
# 0                              2                          1
# 1                              2                          1
# 2                              2                          1
# 3                              1                          1
# 4                              1                          1
# ...                          ...                        ...
# 558206                         1                          2
# 558207                         1                          2
# 558208                         1                          2
# 558209                         1                          2
# 558210                         1                          2
#
#         ChronicCond_Cancer  ChronicCond_ObstrPulmonary  \
# 0                        2                           2
# 1                        2                           2
# 2                        2                           2
# 3                        2                           2
# 4                        2                           1
# ...                    ...                         ...
# 558206                   2                           2
# 558207                   2                           2
# 558208                   2                           2
# 558209                   2                           2
# 558210                   2                           2
#
#         ChronicCond_Depression  ChronicCond_Diabetes  \
# 0                            1                     1
# 1                            1                     1
# 2                            1                     1
# 3                            1                     1
# 4                            1                     2
# ...                        ...                   ...
# 558206                       1                     1
# 558207                       1                     1
# 558208                       1                     1
# 558209                       1                     1
# 558210                       1                     1
#
#         ChronicCond_IschemicHeart  ChronicCond_Osteoporasis  \
# 0                               1                         2
# 1                               1                         2
# 2                               1                         2
# 3                               2                         2
# 4                               1                         2
# ...                           ...                       ...
# 558206                          2                         2
# 558207                          2                         2
# 558208                          2                         2
# 558209                          2                         2
# 558210                          2                         2
#
#         ChronicCond_rheumatoidarthritis  ChronicCond_stroke  \
# 0                                     1                   1
# 1                                     1                   1
# 2                                     1                   1
# 3                                     1                   1
# 4                                     2                   2
# ...                                 ...                 ...
# 558206                                1                   2
# 558207                                1                   2
# 558208                                1                   2
# 558209                                1                   2
# 558210                                1                   2
#
#         IPAnnualReimbursementAmt  IPAnnualDeductibleAmt  \
# 0                          36000                   3204
# 1                          36000                   3204
# 2                          36000                   3204
# 3                           5000                   1068
# 4                          21260                   2136
# ...                          ...                    ...
# 558206                         0                      0
# 558207                         0                      0
# 558208                         0                      0
# 558209                         0                      0
# 558210                         0                      0
#
#         OPAnnualReimbursementAmt  OPAnnualDeductibleAmt
# 0                             60                     70
# 1                             60                     70
# 2                             60                     70
# 3                            250                    320
# 4                            120                    100
# ...                          ...                    ...
# 558206                      5470                   1870
# 558207                      5470                   1870
# 558208                      5470                   1870
# 558209                      5470                   1870
# 558210                      5470                   1870
#
# [558211 rows x 55 columns]

# %% [markdown]
# # Feature Engineering
#
# Features we can derive in the inpatient and outpatient datasets
# - Claim duration
# - Age of patient
# - Is Dead flag
# - Number of diagnoses
# - Number of procedures
# - Admission duration
# - Has attending phys
# - Has operating phys

# %%
from datetime import timedelta

# Calculate the age of the patient at the time their claim was initiated
train_claims['PatientAge'] = (pd.to_datetime(train_claims['ClaimStartDt'], format='%Y-%m-%d') - pd.to_datetime(train_claims['DOB'], format='%Y-%m-%d'))/timedelta(days=365)

# Calculate the duration of the patient's stay
train_claims['PatientStayDur'] = (pd.to_datetime(train_claims['DischargeDt'], format='%Y-%m-%d') - pd.to_datetime(train_claims['AdmissionDt'], format='%Y-%m-%d'))/timedelta(days=1)
train_claims['PatientStayDur'] = train_claims['PatientStayDur'].apply(lambda amt: 0 if pd.isnull(amt) else amt)

# Calculate the duration of the claim
train_claims['ClaimDur'] = (pd.to_datetime(train_claims['ClaimEndDt'], format='%Y-%m-%d') - pd.to_datetime(train_claims['ClaimStartDt'], format='%Y-%m-%d') + timedelta(days=1))/timedelta(days=1)
train_claims['ClaimDur'] = train_claims['ClaimDur'].apply(lambda amt: 0 if pd.isnull(amt) else amt)

# Define whether a patient is dead or not by giving a 0 if dead and 1 if still alive
train_claims['PatientDead'] = train_claims['DOD'].apply(lambda dod: 0 if pd.isnull(dod) else 1)

# %% [markdown]
# # Merging claim data with potential fraud indicators
#
# Once we have all of our features in place, we should merge with the potential fraud data set.
# This will let us set up independent/dependent variables for the decision tree to examine.

# %%
# Use a left outer join so we don't throw away providers that might not have claims.
train_total = train_providers.merge(train_claims, how='left', on='Provider')
train_total
# Out:
#         Provider PotentialFraud      BeneID    ClaimID ClaimStartDt  \
# 0       PRV51001             No   BENE36012   CLM58316   2009-07-04
# 1       PRV51001             No   BENE38773   CLM52334   2009-05-23
# 2       PRV51001             No   BENE98831   CLM36844   2009-02-03
# 3       PRV51001             No  BENE102690   CLM49733   2009-05-04
# 4       PRV51001             No  BENE152088   CLM37205   2009-02-06
# ...          ...            ...         ...        ...          ...
# 558206  PRV57763             No  BENE148535  CLM582682   2009-09-16
# 558207  PRV57763             No  BENE150998  CLM553988   2009-08-30
# 558208  PRV57763             No  BENE151006  CLM610854   2009-10-02
# 558209  PRV57763             No  BENE158531  CLM691834   2009-11-20
# 558210  PRV57763             No  BENE158531  CLM701529   2009-11-26
#
#         ClaimEndDt  InscClaimAmtReimbursed AttendingPhysician  \
# 0       2009-07-08                   36000             340163
# 1       2009-05-25                   12000             346762
# 2       2009-02-08                    3000             383193
# 3       2009-05-18                   42000             383193
# 4       2009-02-06                    4000             402229
# ...            ...                     ...                ...
# 558206  2009-09-25                    1100             321072
# 558207  2009-08-30                     200             321072
# 558208  2009-10-02                      80             321072
# 558209  2009-11-20                    3300             321072
# 558210  2009-11-26                      40             321072
#
#        OperatingPhysician OtherPhysician AdmissionDt ClmAdmitDiagnosisCode  \
# 0                     NaN            NaN  2009-07-04                 29623
# 1                     NaN            NaN  2009-05-23                  0389
# 2                     NaN            NaN  2009-02-03                  5362
# 3                  378091         389113  2009-05-04                 41401
# 4                  329739            NaN  2009-02-06                 80121
# ...                   ...            ...         ...                   ...
# 558206             321072         321072         NaN                   NaN
# 558207                NaN            NaN         NaN                   NaN
# 558208             321072         321072         NaN                   NaN
# 558209                NaN         321072         NaN                   NaN
# 558210                NaN         321072         NaN                   NaN
#
#         DeductibleAmtPaid DischargeDt DiagnosisGroupCode ClmDiagnosisCode_1  \
# 0                  1068.0  2009-07-08                882              29650
# 1                  1068.0  2009-05-25                864               0388
# 2                  1068.0  2009-02-08                353              56211
# 3                  1068.0  2009-05-18                245               4241
# 4                  1068.0  2009-02-06                062              85222
# ...                   ...         ...                ...                ...
# 558206               40.0         NaN                NaN              72740
# 558207                0.0         NaN                NaN               1251
# 558208                0.0         NaN                NaN              79022
# 558209                0.0         NaN                NaN              41406
# 558210                0.0         NaN                NaN               7280
#
#        ClmDiagnosisCode_2 ClmDiagnosisCode_3 ClmDiagnosisCode_4  \
# 0                    2971               3051               1254
# 1                    5849               2841               2762
# 2                    5533               0088               5789
# 3                   42731               4168               2724
# 4                    2724               3310              40390
# ...                   ...                ...                ...
# 558206              78052              56942              71534
# 558207              72981                NaN                NaN
# 558208               4011                427                NaN
# 558209              40290                NaN                NaN
# 558210                NaN                NaN                NaN
#
#        ClmDiagnosisCode_5 ClmDiagnosisCode_6 ClmDiagnosisCode_7  \
# 0                   07070              28260               7823
# 1                    7140               9444                NaN
# 2                   53081              27651               7840
# 3                    4019              42822               2720
# 4                    4501               5866                NaN
# ...                   ...                ...                ...
# 558206               3540                NaN                NaN
# 558207                NaN                NaN                NaN
# 558208                NaN                NaN                NaN
# 558209                NaN                NaN                NaN
# 558210                NaN                NaN                NaN
#
#        ClmDiagnosisCode_8 ClmDiagnosisCode_9 ClmDiagnosisCode_10  \
# 0                   49300                NaN                 NaN
# 1                     NaN                NaN                 NaN
# 2                     NaN                NaN                 NaN
# 3                   45829              53081                 NaN
# 4                     NaN                NaN                 NaN
# ...                   ...                ...                 ...
# 558206                NaN                NaN                 NaN
# 558207                NaN                NaN                 NaN
# 558208                NaN                NaN                 NaN
# 558209                NaN                NaN                 NaN
# 558210                NaN                NaN                 NaN
#
#         ClmProcedureCode_1  ClmProcedureCode_2  ClmProcedureCode_3  \
# 0                      NaN                 NaN                 NaN
# 1                      NaN                 NaN                 NaN
# 2                      NaN                 NaN                 NaN
# 3                   3521.0              2724.0                 NaN
# 4                   8659.0                 NaN                 NaN
# ...                    ...                 ...                 ...
# 558206                 NaN                 NaN                 NaN
# 558207                 NaN                 NaN                 NaN
# 558208                 NaN                 NaN                 NaN
# 558209                 NaN                 NaN                 NaN
# 558210                 NaN                 NaN                 NaN
#
#         ClmProcedureCode_4  ClmProcedureCode_5  ClmProcedureCode_6  In/Out  \
# 0                      NaN                 NaN                 NaN       1
# 1                      NaN                 NaN                 NaN       1
# 2                      NaN                 NaN                 NaN       1
# 3                      NaN                 NaN                 NaN       1
# 4                      NaN                 NaN                 NaN       1
# ...                    ...                 ...                 ...     ...
# 558206                 NaN                 NaN                 NaN       0
# 558207                 NaN                 NaN                 NaN       0
# 558208                 NaN                 NaN                 NaN       0
# 558209                 NaN                 NaN                 NaN       0
# 558210                 NaN                 NaN                 NaN       0
#
#                DOB  DOD  Gender  Race RenalDiseaseIndicator  State  County  \
# 0       1940-07-01  NaN       1     1                     0      1     510
# 1       1938-05-01  NaN       1     1                     0      1     160
# 2       1934-11-01  NaN       2     1                     0      1     510
# 3       1929-11-01  NaN       2     1                     Y      1     160
# 4       1913-09-01  NaN       2     1                     Y      1     160
# ...            ...  ...     ...   ...                   ...    ...     ...
# 558206  1940-02-01  NaN       2     2                     0     21     210
# 558207  1958-12-01  NaN       1     2                     0     21     210
# 558208  1963-08-01  NaN       2     1                     Y     21     210
# 558209  1952-02-01  NaN       2     2                     0     21     210
# 558210  1952-02-01  NaN       2     2                     0     21     210
#
#         NoOfMonths_PartACov  NoOfMonths_PartBCov  ChronicCond_Alzheimer  \
# 0                        12                   12                      2
# 1                        12                   12                      2
# 2                        12                   12                      1
# 3                        12                   12                      2
# 4                        12                   12                      1
# ...                     ...                  ...                    ...
# 558206                   12                   12                      1
# 558207                   12                   12                      2
# 558208                   12                   12                      2
# 558209                   12                   12                      2
# 558210                   12                   12                      2
#
#         ChronicCond_Heartfailure  ChronicCond_KidneyDisease  \
# 0                              1                          1
# 1                              2                          1
# 2                              1                          2
# 3                              1                          1
# 4                              1                          1
# ...                          ...                        ...
# 558206                         2                          2
# 558207                         2                          2
# 558208                         2                          1
# 558209                         2                          2
# 558210                         2                          2
#
#         ChronicCond_Cancer  ChronicCond_ObstrPulmonary  \
# 0                        2                           2
# 1                        2                           2
# 2                        2                           2
# 3                        2                           1
# 4                        1                           1
# ...                    ...                         ...
# 558206                   2                           2
# 558207                   2                           2
# 558208                   1                           1
# 558209                   2                           2
# 558210                   2                           2
#
#         ChronicCond_Depression  ChronicCond_Diabetes  \
# 0                            1                     1
# 1                            2                     2
# 2                            1                     1
# 3                            1                     1
# 4                            1                     1
# ...                        ...                   ...
# 558206                       1                     1
# 558207                       2                     2
# 558208                       2                     1
# 558209                       2                     1
# 558210                       2                     1
#
#         ChronicCond_IschemicHeart  ChronicCond_Osteoporasis  \
# 0                               1                         2
# 1                               2                         2
# 2                               1                         2
# 3                               1                         2
# 4                               1                         2
# ...                           ...                       ...
# 558206                          1                         1
# 558207                          2                         2
# 558208                          1                         2
# 558209                          1                         2
# 558210                          1                         2
#
#         ChronicCond_rheumatoidarthritis  ChronicCond_stroke  \
# 0                                     2                   1
# 1                                     2                   2
# 2                                     1                   2
# 3                                     1                   2
# 4                                     1                   1
# ...                                 ...                 ...
# 558206                                1                   2
# 558207                                2                   2
# 558208                                2                   2
# 558209                                2                   2
# 558210                                2                   2
#
#         IPAnnualReimbursementAmt  IPAnnualDeductibleAmt  \
# 0                          36000                   1068
# 1                          95000                   2136
# 2                           3000                   1068
# 3                         143800                   4272
# 4                         111710                   4272
# ...                          ...                    ...
# 558206                         0                      0
# 558207                         0                      0
# 558208                     28150                   2136
# 558209                         0                      0
# 558210                         0                      0
#
#         OPAnnualReimbursementAmt  OPAnnualDeductibleAmt  PatientAge  \
# 0                           3520                    140   69.054795
# 1                           2270                    900   71.109589
# 2                              0                      0   74.309589
# 3                            880                     70   79.558904
# 4                             80                     70   95.498630
# ...                          ...                    ...         ...
# 558206                      1780                    320   69.671233
# 558207                       200                    200   50.780822
# 558208                      1980                    500   46.202740
# 558209                      3700                    240   57.841096
# 558210                      3700                    240   57.857534
#
#         PatientStayDur  ClaimDur  PatientDead
# 0                  4.0       5.0            0
# 1                  2.0       3.0            0
# 2                  5.0       6.0            0
# 3                 14.0      15.0            0
# 4                  0.0       1.0            0
# ...                ...       ...          ...
# 558206             0.0      10.0            0
# 558207             0.0       1.0            0
# 558208             0.0       1.0            0
# 558209             0.0       1.0            0
# 558210             0.0       1.0            0
#
# [558211 rows x 60 columns]

# %%
# Function that constructs a DataFrame of stats for given columns.
#    groupby_obj -> result of a groupby operation on a particular column
#    cols -> iterable of strings containing column names to calculate stats for
def stat_analysis(groupby_obj, cols):
    new_cols = []
    new_col_names = []
    for c in cols:
        new_cols += [groupby_obj[c].mean(), 
                     groupby_obj[c].median(),
                     groupby_obj[c].var().apply(lambda v: v if not pd.isnull(v) else 0),
                     groupby_obj[c].std().apply(lambda v: v if not pd.isnull(v) else 0),
                     groupby_obj[c].min(),
                     groupby_obj[c].max()]
        new_col_names += [f'Mean{c}',
                          f'Median{c}',
                          f'Var{c}',
                          f'Std{c}',
                          f'Min{c}',
                          f'Max{c}']
    
    return pd.DataFrame(data=zip(*new_cols), index=new_cols[0].index, columns=new_col_names)

# Group the data we've collected by provider so it can be analyzed with the stat_analysis function
train_total_gb = train_total.groupby(['Provider'])

# Calculate aggregated statistics on the selected columns
agg_frame = stat_analysis(train_total_gb, ['InscClaimAmtReimbursed', 'DeductibleAmtPaid', 'PatientAge', 'Gender', 'Race', 'State', 'County', 'PatientStayDur', 'ClaimDur', 'PatientDead', 'IPAnnualReimbursementAmt', 'OPAnnualReimbursementAmt'])

# Join the aggregated stats frame with the fraud flag data
agg_frame = train_providers.merge(agg_frame, how='left', on='Provider')

# Set the index to the provider ID and drop the data from the Provider column
agg_frame.set_index(['Provider'], inplace=True)
agg_frame
# Out:
# 0               4.760500e+05
# PRV51005                            70               2.416277e+05
# PRV51007                            80               2.055694e+06
# ...                                ...                        ...
# PRV57759                            65               6.738444e+05
# PRV57760                            85               9.609892e+04
# PRV57761                            70               1.750302e+05
# PRV57762                          1900               0.000000e+00
# PRV57763                            90               4.569921e+05
#
#           StdInscClaimAmtReimbursed  MinInscClaimAmtReimbursed  \
# Provider
# PRV51001               10796.091144                         10
# PRV51003                7309.794729                          0
# PRV51004                 689.963754                          0
# PRV51005                 491.556392                          0
# PRV51007                1433.769116                          0
# ...                             ...                        ...
# PRV57759                 820.880286                         10
# PRV57760                 309.998254                         20
# PRV57761                 418.366092                          0
# PRV57762                   0.000000                       1900
# PRV57763                 676.011928                          0
#
#           MaxInscClaimAmtReimbursed  MeanDeductibleAmtPaid  \
# Provider
# PRV51001                      42000             213.600000
# PRV51003                      57000             502.166667
# PRV51004                       3300               2.080537
# PRV51005                       4080               3.175966
# PRV51007                      10000              45.333333
# ...                             ...                    ...
# PRV57759                       3300               4.642857
# PRV57760                       1100               0.000000
# PRV57761                       2200               4.512195
# PRV57762                       1900               0.000000
# PRV57763                       3300               3.305085
#
#           MedianDeductibleAmtPaid  VarDeductibleAmtPaid  StdDeductibleAmtPaid  \
# Provider
# PRV51001                      0.0         190104.000000            436.009174
# PRV51003                      0.0         285778.384224            534.582439
# PRV51004                      0.0            124.696173             11.166744
# PRV51005                      0.0            289.904576             17.026584
# PRV51007                      0.0          46147.943662            214.820724
# ...                           ...                   ...                   ...
# PRV57759                      0.0            336.904762             18.354966
# PRV57760                      0.0              0.000000              0.000000
# PRV57761                      0.0            279.388738             16.714926
# PRV57762                      0.0              0.000000              0.000000
# PRV57763                      0.0            242.829205             15.582978
#
#           MinDeductibleAmtPaid  MaxDeductibleAmtPaid  MeanPatientAge  \
# Provider
# PRV51001                   0.0                1068.0       78.263014
# PRV51003                   0.0                1068.0       69.587422
# PRV51004                   0.0                 100.0       71.787570
# PRV51005                   0.0                 200.0       70.075247
# PRV51007                   0.0                1068.0       68.837291
# ...                        ...                   ...             ...
# PRV57759                   0.0                  90.0       73.476419
# PRV57760                   0.0                   0.0       61.016438
# PRV57761                   0.0                  90.0       71.545306
# PRV57762                   0.0                   0.0       67.786301
# PRV57763                   0.0                 100.0       73.643046
#
#           MedianPatientAge  VarPatientAge  StdPatientAge  MinPatientAge  \
# Provider
# PRV51001         79.558904     142.066116      11.919149      57.073973
# PRV51003         71.686301     181.370344      13.467381      37.671233
# PRV51004         72.830137     167.171740      12.929491      25.794521
# PRV51005         70.731507     178.291931      13.352600      28.438356
# PRV51007         70.030137     214.170253      14.634557      26.010959
# ...                    ...            ...            ...            ...
# PRV57759         72.553425      77.239828       8.788619      55.863014
# PRV57760         58.689041      96.119167       9.804038      43.383562
# PRV57761         73.606849     272.980007      16.522107      30.145205
# PRV57762         67.786301       0.000000       0.000000      67.786301
# PRV57763         73.032877     187.072779      13.677455      43.063014
#
#           MaxPatientAge  MeanGender  MedianGender  VarGender  StdGender  \
# Provider
# PRV51001      97.539726    1.640000           2.0   0.240000   0.489898
# PRV51003      96.958904    1.590909           2.0   0.243581   0.493539
# PRV51004      99.758904    1.691275           2.0   0.214856   0.463525
# PRV51005     100.887671    1.561373           2.0   0.246445   0.496432
# PRV51007      99.210959    1.527778           2.0   0.252739   0.502731
# ...                 ...         ...           ...        ...        ...
# PRV57759      89.282192    1.428571           1.0   0.253968   0.503953
# PRV57760      82.449315    1.227273           1.0   0.183983   0.428932
# PRV57761      98.682192    1.512195           2.0   0.252936   0.502927
# PRV57762      67.786301    1.000000           1.0   0.000000   0.000000
# PRV57763      99.230137    1.525424           2.0   0.251485   0.501483
#
#           MinGender  MaxGender  MeanRace  MedianRace   VarRace   StdRace  \
# Provider
# PRV51001          1          2  1.160000         1.0  0.140000  0.374166
# PRV51003          1          2  1.212121         1.0  0.260005  0.509906
# PRV51004          1          2  1.228188         1.0  0.244876  0.494849
# PRV51005          1          2  1.242060         1.0  0.200807  0.448115
# PRV51007          1          2  1.194444         1.0  0.158842  0.398550
# ...             ...        ...       ...         ...       ...       ...
# PRV57759          1          2  1.642857         1.0  2.015873  1.419814
# PRV57760          1          2  1.181818         1.0  0.155844  0.394771
# PRV57761          1          2  1.304878         1.0  0.831828  0.912046
# PRV57762          1          1  1.000000         1.0  0.000000  0.000000
# PRV57763          1          2  1.203390         1.0  0.231783  0.481439
#
#           MinRace  MaxRace  MeanState  MedianState    VarState   StdState  \
# Provider
# PRV51001        1        2   1.000000          1.0    0.000000   0.000000
# PRV51003        1        5   3.628788          1.0   17.945119   4.236168
# PRV51004        1        3  12.402685          1.0  204.566479  14.302674
# PRV51005        1        3   1.327897          1.0    7.529848   2.744057
# PRV51007        1        2   3.000000          1.0   44.619718   6.679799
# ...           ...      ...        ...          ...         ...        ...
# PRV57759        1        5  45.000000         45.0    0.000000   0.000000
# PRV57760        1        2  45.000000         45.0    0.000000   0.000000
# PRV57761        1        5  10.000000         10.0    0.000000   0.000000
# PRV57762        1        1  21.000000         21.0    0.000000   0.000000
# PRV57763        1        3  22.779661         21.0   32.190352   5.673654
#
#           MinState  MaxState  MeanCounty  MedianCounty      VarCounty  \
# Provider
# PRV51001         1         1  460.000000         440.0   22866.666667
# PRV51003         1        11  300.386364         330.0   21198.330500
# PRV51004         1        52  327.181208         360.0   23424.433158
# PRV51005         1        25  483.880687         510.0   17536.749498
# PRV51007         1        25  375.416667         380.0    1946.302817
# ...            ...       ...         ...           ...            ...
# PRV57759        45        45  361.071429         120.0  108482.142857
# PRV57760        45        45  439.772727         292.0   49045.898268
# PRV57761        10        10  402.317073         410.0     484.688347
# PRV57762        21        21  230.000000         230.0       0.000000
# PRV57763        21        51  220.254237         210.0    1935.832247
#
#            StdCounty  MinCounty  MaxCounty  MeanPatientStayDur  \
# Provider
# PRV51001  151.217283        160        660            1.000000
# PRV51003  145.596465         20        851            2.424242
# PRV51004  153.050427         10        770            0.000000
# PRV51005  132.426393        110        660            0.000000
# PRV51007   44.116922        280        630            0.222222
# ...              ...        ...        ...                 ...
# PRV57759  329.366275        120        795            0.000000
# PRV57760  221.463086        292        770            0.000000
# PRV57761   22.015639        340        410            0.000000
# PRV57762    0.000000        230        230            0.000000
# PRV57763   43.998094         10        360            0.000000
#
#           MedianPatientStayDur  VarPatientStayDur  StdPatientStayDur  \
# Provider
# PRV51001                   0.0           9.000000           3.000000
# PRV51003                   0.0          15.894980           3.986851
# PRV51004                   0.0           0.000000           0.000000
# PRV51005                   0.0           0.000000           0.000000
# PRV51007                   0.0           1.217527           1.103416
# ...                        ...                ...                ...
# PRV57759                   0.0           0.000000           0.000000
# PRV57760                   0.0           0.000000           0.000000
# PRV57761                   0.0           0.000000           0.000000
# PRV57762                   0.0           0.000000           0.000000
# PRV57763                   0.0           0.000000           0.000000
#
#           MinPatientStayDur  MaxPatientStayDur  MeanClaimDur  MedianClaimDur  \
# Provider
# PRV51001                0.0               14.0      2.440000             1.0
# PRV51003                0.0               27.0      4.674242             2.5
# PRV51004                0.0                0.0      2.429530             1.0
# PRV51005                0.0                0.0      2.088412             1.0
# PRV51007                0.0                7.0      1.958333             1.0
# ...                     ...                ...           ...             ...
# PRV57759                0.0                0.0      3.142857             1.0
# PRV57760                0.0                0.0      1.318182             1.0
# PRV57761                0.0                0.0      2.390244             1.0
# PRV57762                0.0                0.0      1.000000             1.0
# PRV57763                0.0                0.0      2.720339             1.0
#
#           VarClaimDur  StdClaimDur  MinClaimDur  MaxClaimDur  MeanPatientDead  \
# Provider
# PRV51001    11.340000     3.367492          1.0         15.0         0.000000
# PRV51003    30.419789     5.515414          1.0         28.0         0.007576
# PRV51004    22.881825     4.783495          1.0         21.0         0.006711
# PRV51005    16.871043     4.107437          1.0         21.0         0.003433
# PRV51007    11.871479     3.445501          1.0         21.0         0.013889
# ...               ...          ...          ...          ...              ...
# PRV57759    39.682540     6.299408          1.0         21.0         0.000000
# PRV57760     2.227273     1.492405          1.0          8.0         0.000000
# PRV57761    23.598916     4.857872          1.0         21.0         0.012195
# PRV57762     0.000000     0.000000          1.0          1.0         0.000000
# PRV57763    24.100608     4.909237          1.0         21.0         0.000000
#
#           MedianPatientDead  VarPatientDead  StdPatientDead  MinPatientDead  \
# Provider
# PRV51001                0.0        0.000000        0.000000               0
# PRV51003                0.0        0.007576        0.087039               0
# PRV51004                0.0        0.006711        0.081923               0
# PRV51005                0.0        0.003425        0.058520               0
# PRV51007                0.0        0.013889        0.117851               0
# ...                     ...             ...             ...             ...
# PRV57759                0.0        0.000000        0.000000               0
# PRV57760                0.0        0.000000        0.000000               0
# PRV57761                0.0        0.012195        0.110432               0
# PRV57762                0.0        0.000000        0.000000               0
# PRV57763                0.0        0.000000        0.000000               0
#
#           MaxPatientDead  MeanIPAnnualReimbursementAmt  \
# Provider
# PRV51001               0                  17606.000000
# PRV51003               1                   7568.181818
# PRV51004               1                   4351.879195
# PRV51005               1                   3623.991416
# PRV51007               1                   3050.000000
# ...                  ...                           ...
# PRV57759               0                   3962.142857
# PRV57760               0                   2785.454545
# PRV57761               1                   7026.585366
# PRV57762               0                  15000.000000
# PRV57763               0                   3599.237288
#
#           MedianIPAnnualReimbursementAmt  VarIPAnnualReimbursementAmt  \
# Provider
# PRV51001                               0                 1.512858e+09
# PRV51003                            4580                 1.008212e+08
# PRV51004                               0                 9.780346e+07
# PRV51005                               0                 9.386755e+07
# PRV51007                               0                 3.229149e+07
# ...                                  ...                          ...
# PRV57759                               0                 7.539154e+07
# PRV57760                               0                 1.216344e+07
# PRV57761                               0                 2.169850e+08
# PRV57762                           15000                 0.000000e+00
# PRV57763                               0                 6.865767e+07
#
#           StdIPAnnualReimbursementAmt  MinIPAnnualReimbursementAmt  \
# Provider
# PRV51001                 38895.477458                            0
# PRV51003                 10040.975578                            0
# PRV51004                  9889.562978                            0
# PRV51005                  9688.526566                            0
# PRV51007                  5682.560175                            0
# ...                               ...                          ...
# PRV57759                  8682.829952                            0
# PRV57760                  3487.611718                            0
# PRV57761                 14730.410655                            0
# PRV57762                     0.000000                        15000
# PRV57763                  8285.992212                            0
#
#           MaxIPAnnualReimbursementAmt  MeanOPAnnualReimbursementAmt  \
# Provider
# PRV51001                       143800                   2615.200000
# PRV51003                        57000                   2678.181818
# PRV51004                        51500                   2194.899329
# PRV51005                       144000                   2109.733906
# PRV51007                        24600                   1729.722222
# ...                               ...                           ...
# PRV57759                        29000                   3241.785714
# PRV57760                         7160                   1492.727273
# PRV57761                        75000                   2928.414634
# PRV57762                        15000                   2540.000000
# PRV57763                        57000                   3108.898305
#
#           MedianOPAnnualReimbursementAmt  VarOPAnnualReimbursementAmt  \
# Provider
# PRV51001                            1590                 8.845726e+06
# PRV51003                            1235                 2.694352e+07
# PRV51004                            1140                 1.022727e+07
# PRV51005                            1200                 1.568327e+07
# PRV51007                            1290                 2.636972e+06
# ...                                  ...                          ...
# PRV57759                            1525                 1.821784e+07
# PRV57760                             680                 2.063478e+06
# PRV57761                            1390                 1.946157e+07
# PRV57762                            2540                 0.000000e+00
# PRV57763                            1710                 2.588769e+07
#
#           StdOPAnnualReimbursementAmt  MinOPAnnualReimbursementAmt  \
# Provider
# PRV51001                  2974.176525                            0
# PRV51003                  5190.714819                            0
# PRV51004                  3198.010914                            0
# PRV51005                  3960.211085                           10
# PRV51007                  1623.875535                           30
# ...                               ...                          ...
# PRV57759                  4268.236737                           80
# PRV57760                  1436.481090                          360
# PRV57761                  4411.526840                           20
# PRV57762                     0.000000                         2540
# PRV57763                  5087.994884                           40
#
#           MaxOPAnnualReimbursementAmt
# Provider
# PRV51001                        13460
# PRV51003                        31880
# PRV51004                        20900
# PRV51005                        97510
# PRV51007                         6060
# ...                               ...
# PRV57759                        14650
# PRV57760                         4980
# PRV57761                        25090
# PRV57762                         2540
# PRV57763                        30430
#
# [5410 rows x 73 columns]

# %% [markdown]
# # Standard Deviation Calculations
#
# With standard deviations now calculated for numeric fields, we can figure out how often claims are made beyond multiples of the standard deviation. This cell providers helper functions that perform that analysis against data internal to a provider, as well as comparing provider metrics against global mean/stddev

# %%
# Determines how many entries in a column are more than n std devs away from the mean
#   mean -> the mean to compare against
#   std_dev -> the std deviation to use
#   num_std_devs -> the number of standard deviations to use in calculations
#   col -> the column to apply calculations to
def num_std_devs_exceeded(mean, std_dev, num_std_devs, col):
    n = 0
    for entry in col:
        if entry > mean + num_std_devs * std_dev or entry < mean - num_std_devs * std_dev:
            n += 1

    return n

# Performs standard deviation analysis against previously collected statistics
#   index_name -> the name of the column to use as the index (in this notebook, 'Provider')
#   dev_result_col -> the name of the column to write calculations to
#   num_deviations -> the number of std devs to use in outlier analysis
#   stat_gen -> generator that yields a 4-tuple containing (current index, mean, std dev, column data) needed for calculations
def std_dev_analysis(index_name, dev_result_col, num_deviations, stat_gen):
    # Set up empty dictionary that maps index to a list of index values, and calculation results to a list of results
    result_dict = {index_name: [], dev_result_col: []}

    # For each group in the GroupBy object, get the mean and std dev, then calculate how many outliers there are.
    # Add the results to the result dictionary
    for key, mean, std_dev, column_data in stat_gen:
        outliers = num_std_devs_exceeded(mean, std_dev, num_deviations, column_data)

        result_dict[index_name].append(key)
        result_dict[dev_result_col].append(outliers)

    # Create a new DataFrame using the results of our calculations
    return pd.DataFrame(data=result_dict)

# Generator that provides the mean and std dev internal to a single provider
def internal_std_dev_generator(aggregated_analysis, group_by_obj, column):
    # Set up names for mean and std dev columns
    mean_key = f'Mean{column}'
    std_key = f'Std{column}'

    for key in group_by_obj.groups:
        mean = aggregated_analysis.loc[key][mean_key]
        std = aggregated_analysis.loc[key][std_key]

        yield (key, mean, std, group_by_obj.get_group(key)[column])

# Generator that provides the global mean and std dev regardless of provider
def global_std_dev_generator(global_data, group_by_obj, column):
    mean = global_data[column].mean()
    std = global_data[column].std()

    for key in group_by_obj.groups:
        yield (key, mean, std, group_by_obj.get_group(key)[column])

def internal_std_dev_to_frame(col, num_std_devs):
    internal_stat_gen = internal_std_dev_generator(agg_frame, train_total_gb, col)
    dev_frame = std_dev_analysis('Provider', f'{col}{num_std_devs}DeviationsInternal', num_std_devs, internal_stat_gen)

    return dev_frame

def global_std_dev_to_frame(col, num_std_devs):
    global_stat_gen = global_std_dev_generator(train_total, train_total_gb, col)
    dev_frame = std_dev_analysis('Provider', f'{col}{num_std_devs}DeviationsGlobal', num_std_devs, global_stat_gen)

    return dev_frame

# %% [markdown]
# # Select variables for std deviation analysis
#
# The cell below uses the functions defined in the previous cell to perform outlier analysis of provider metrics against internal and global data

# %%
from functools import reduce
dev_frames = []

# Perform internal standard deviation analysis and merge results with the aggregated frame
dev_frames.append(internal_std_dev_to_frame('PatientAge', 1))
dev_frames.append(global_std_dev_to_frame('PatientAge', 1))
dev_frames.append(internal_std_dev_to_frame('InscClaimAmtReimbursed', 1))
dev_frames.append(global_std_dev_to_frame('InscClaimAmtReimbursed', 1))
dev_frames.append(internal_std_dev_to_frame('DeductibleAmtPaid', 1))
dev_frames.append(global_std_dev_to_frame('DeductibleAmtPaid', 1))
dev_frames.append(internal_std_dev_to_frame('IPAnnualReimbursementAmt', 1))
dev_frames.append(global_std_dev_to_frame('IPAnnualReimbursementAmt', 1))
dev_frames.append(internal_std_dev_to_frame('OPAnnualReimbursementAmt', 1))
dev_frames.append(global_std_dev_to_frame('OPAnnualReimbursementAmt', 1))

# Consolidate 
total_dev_frame = reduce(lambda left, right: left.merge(right, how='left', on='Provider'), dev_frames)

# Create final frame to be used in decision tree
final_frame = agg_frame.merge(total_dev_frame, how='left', on='Provider')
final_frame
# Out:
# PatientAge  \
# 0                      0.0                1068.0       78.263014
# 1                      0.0                1068.0       69.587422
# 2                      0.0                 100.0       71.787570
# 3                      0.0                 200.0       70.075247
# 4                      0.0                1068.0       68.837291
# ...                    ...                   ...             ...
# 5405                   0.0                  90.0       73.476419
# 5406                   0.0                   0.0       61.016438
# 5407                   0.0                  90.0       71.545306
# 5408                   0.0                   0.0       67.786301
# 5409                   0.0                 100.0       73.643046
#
#       MedianPatientAge  VarPatientAge  StdPatientAge  MinPatientAge  \
# 0            79.558904     142.066116      11.919149      57.073973
# 1            71.686301     181.370344      13.467381      37.671233
# 2            72.830137     167.171740      12.929491      25.794521
# 3            70.731507     178.291931      13.352600      28.438356
# 4            70.030137     214.170253      14.634557      26.010959
# ...                ...            ...            ...            ...
# 5405         72.553425      77.239828       8.788619      55.863014
# 5406         58.689041      96.119167       9.804038      43.383562
# 5407         73.606849     272.980007      16.522107      30.145205
# 5408         67.786301       0.000000       0.000000      67.786301
# 5409         73.032877     187.072779      13.677455      43.063014
#
#       MaxPatientAge  MeanGender  MedianGender  VarGender  StdGender  \
# 0         97.539726    1.640000           2.0   0.240000   0.489898
# 1         96.958904    1.590909           2.0   0.243581   0.493539
# 2         99.758904    1.691275           2.0   0.214856   0.463525
# 3        100.887671    1.561373           2.0   0.246445   0.496432
# 4         99.210959    1.527778           2.0   0.252739   0.502731
# ...             ...         ...           ...        ...        ...
# 5405      89.282192    1.428571           1.0   0.253968   0.503953
# 5406      82.449315    1.227273           1.0   0.183983   0.428932
# 5407      98.682192    1.512195           2.0   0.252936   0.502927
# 5408      67.786301    1.000000           1.0   0.000000   0.000000
# 5409      99.230137    1.525424           2.0   0.251485   0.501483
#
#       MinGender  MaxGender  MeanRace  MedianRace   VarRace   StdRace  MinRace  \
# 0             1          2  1.160000         1.0  0.140000  0.374166        1
# 1             1          2  1.212121         1.0  0.260005  0.509906        1
# 2             1          2  1.228188         1.0  0.244876  0.494849        1
# 3             1          2  1.242060         1.0  0.200807  0.448115        1
# 4             1          2  1.194444         1.0  0.158842  0.398550        1
# ...         ...        ...       ...         ...       ...       ...      ...
# 5405          1          2  1.642857         1.0  2.015873  1.419814        1
# 5406          1          2  1.181818         1.0  0.155844  0.394771        1
# 5407          1          2  1.304878         1.0  0.831828  0.912046        1
# 5408          1          1  1.000000         1.0  0.000000  0.000000        1
# 5409          1          2  1.203390         1.0  0.231783  0.481439        1
#
#       MaxRace  MeanState  MedianState    VarState   StdState  MinState  \
# 0           2   1.000000          1.0    0.000000   0.000000         1
# 1           5   3.628788          1.0   17.945119   4.236168         1
# 2           3  12.402685          1.0  204.566479  14.302674         1
# 3           3   1.327897          1.0    7.529848   2.744057         1
# 4           2   3.000000          1.0   44.619718   6.679799         1
# ...       ...        ...          ...         ...        ...       ...
# 5405        5  45.000000         45.0    0.000000   0.000000        45
# 5406        2  45.000000         45.0    0.000000   0.000000        45
# 5407        5  10.000000         10.0    0.000000   0.000000        10
# 5408        1  21.000000         21.0    0.000000   0.000000        21
# 5409        3  22.779661         21.0   32.190352   5.673654        21
#
#       MaxState  MeanCounty  MedianCounty      VarCounty   StdCounty  \
# 0            1  460.000000         440.0   22866.666667  151.217283
# 1           11  300.386364         330.0   21198.330500  145.596465
# 2           52  327.181208         360.0   23424.433158  153.050427
# 3           25  483.880687         510.0   17536.749498  132.426393
# 4           25  375.416667         380.0    1946.302817   44.116922
# ...        ...         ...           ...            ...         ...
# 5405        45  361.071429         120.0  108482.142857  329.366275
# 5406        45  439.772727         292.0   49045.898268  221.463086
# 5407        10  402.317073         410.0     484.688347   22.015639
# 5408        21  230.000000         230.0       0.000000    0.000000
# 5409        51  220.254237         210.0    1935.832247   43.998094
#
#       MinCounty  MaxCounty  MeanPatientStayDur  MedianPatientStayDur  \
# 0           160        660            1.000000                   0.0
# 1            20        851            2.424242                   0.0
# 2            10        770            0.000000                   0.0
# 3           110        660            0.000000                   0.0
# 4           280        630            0.222222                   0.0
# ...         ...        ...                 ...                   ...
# 5405        120        795            0.000000                   0.0
# 5406        292        770            0.000000                   0.0
# 5407        340        410            0.000000                   0.0
# 5408        230        230            0.000000                   0.0
# 5409         10        360            0.000000                   0.0
#
#       VarPatientStayDur  StdPatientStayDur  MinPatientStayDur  \
# 0              9.000000           3.000000                0.0
# 1             15.894980           3.986851                0.0
# 2              0.000000           0.000000                0.0
# 3              0.000000           0.000000                0.0
# 4              1.217527           1.103416                0.0
# ...                 ...                ...                ...
# 5405           0.000000           0.000000                0.0
# 5406           0.000000           0.000000                0.0
# 5407           0.000000           0.000000                0.0
# 5408           0.000000           0.000000                0.0
# 5409           0.000000           0.000000                0.0
#
#       MaxPatientStayDur  MeanClaimDur  MedianClaimDur  VarClaimDur  \
# 0                  14.0      2.440000             1.0    11.340000
# 1                  27.0      4.674242             2.5    30.419789
# 2                   0.0      2.429530             1.0    22.881825
# 3                   0.0      2.088412             1.0    16.871043
# 4                   7.0      1.958333             1.0    11.871479
# ...                 ...           ...             ...          ...
# 5405                0.0      3.142857             1.0    39.682540
# 5406                0.0      1.318182             1.0     2.227273
# 5407                0.0      2.390244             1.0    23.598916
# 5408                0.0      1.000000             1.0     0.000000
# 5409                0.0      2.720339             1.0    24.100608
#
#       StdClaimDur  MinClaimDur  MaxClaimDur  MeanPatientDead  \
# 0        3.367492          1.0         15.0         0.000000
# 1        5.515414          1.0         28.0         0.007576
# 2        4.783495          1.0         21.0         0.006711
# 3        4.107437          1.0         21.0         0.003433
# 4        3.445501          1.0         21.0         0.013889
# ...           ...          ...          ...              ...
# 5405     6.299408          1.0         21.0         0.000000
# 5406     1.492405          1.0          8.0         0.000000
# 5407     4.857872          1.0         21.0         0.012195
# 5408     0.000000          1.0          1.0         0.000000
# 5409     4.909237          1.0         21.0         0.000000
#
#       MedianPatientDead  VarPatientDead  StdPatientDead  MinPatientDead  \
# 0                   0.0        0.000000        0.000000               0
# 1                   0.0        0.007576        0.087039               0
# 2                   0.0        0.006711        0.081923               0
# 3                   0.0        0.003425        0.058520               0
# 4                   0.0        0.013889        0.117851               0
# ...                 ...             ...             ...             ...
# 5405                0.0        0.000000        0.000000               0
# 5406                0.0        0.000000        0.000000               0
# 5407                0.0        0.012195        0.110432               0
# 5408                0.0        0.000000        0.000000               0
# 5409                0.0        0.000000        0.000000               0
#
#       MaxPatientDead  MeanIPAnnualReimbursementAmt  \
# 0                  0                  17606.000000
# 1                  1                   7568.181818
# 2                  1                   4351.879195
# 3                  1                   3623.991416
# 4                  1                   3050.000000
# ...              ...                           ...
# 5405               0                   3962.142857
# 5406               0                   2785.454545
# 5407               1                   7026.585366
# 5408               0                  15000.000000
# 5409               0                   3599.237288
#
#       MedianIPAnnualReimbursementAmt  VarIPAnnualReimbursementAmt  \
# 0                                  0                 1.512858e+09
# 1                               4580                 1.008212e+08
# 2                                  0                 9.780346e+07
# 3                                  0                 9.386755e+07
# 4                                  0                 3.229149e+07
# ...                              ...                          ...
# 5405                               0                 7.539154e+07
# 5406                               0                 1.216344e+07
# 5407                               0                 2.169850e+08
# 5408                           15000                 0.000000e+00
# 5409                               0                 6.865767e+07
#
#       StdIPAnnualReimbursementAmt  MinIPAnnualReimbursementAmt  \
# 0                    38895.477458                            0
# 1                    10040.975578                            0
# 2                     9889.562978                            0
# 3                     9688.526566                            0
# 4                     5682.560175                            0
# ...                           ...                          ...
# 5405                  8682.829952                            0
# 5406                  3487.611718                            0
# 5407                 14730.410655                            0
# 5408                     0.000000                        15000
# 5409                  8285.992212                            0
#
#       MaxIPAnnualReimbursementAmt  MeanOPAnnualReimbursementAmt  \
# 0                          143800                   2615.200000
# 1                           57000                   2678.181818
# 2                           51500                   2194.899329
# 3                          144000                   2109.733906
# 4                           24600                   1729.722222
# ...                           ...                           ...
# 5405                        29000                   3241.785714
# 5406                         7160                   1492.727273
# 5407                        75000                   2928.414634
# 5408                        15000                   2540.000000
# 5409                        57000                   3108.898305
#
#       MedianOPAnnualReimbursementAmt  VarOPAnnualReimbursementAmt  \
# 0                               1590                 8.845726e+06
# 1                               1235                 2.694352e+07
# 2                               1140                 1.022727e+07
# 3                               1200                 1.568327e+07
# 4                               1290                 2.636972e+06
# ...                              ...                          ...
# 5405                            1525                 1.821784e+07
# 5406                             680                 2.063478e+06
# 5407                            1390                 1.946157e+07
# 5408                            2540                 0.000000e+00
# 5409                            1710                 2.588769e+07
#
#       StdOPAnnualReimbursementAmt  MinOPAnnualReimbursementAmt  \
# 0                     2974.176525                            0
# 1                     5190.714819                            0
# 2                     3198.010914                            0
# 3                     3960.211085                           10
# 4                     1623.875535                           30
# ...                           ...                          ...
# 5405                  4268.236737                           80
# 5406                  1436.481090                          360
# 5407                  4411.526840                           20
# 5408                     0.000000                         2540
# 5409                  5087.994884                           40
#
#       MaxOPAnnualReimbursementAmt  PatientAge1DeviationsInternal  \
# 0                           13460                              8
# 1                           31880                             39
# 2                           20900                             50
# 3                           97510                            306
# 4                            6060                             19
# ...                           ...                            ...
# 5405                        14650                              8
# 5406                         4980                              6
# 5407                        25090                             23
# 5408                         2540                              0
# 5409                        30430                             40
#
#       PatientAge1DeviationsGlobal  InscClaimAmtReimbursed1DeviationsInternal  \
# 0                              10                                          2
# 1                              43                                         17
# 2                              47                                         15
# 3                             305                                         92
# 4                              24                                          4
# ...                           ...                                        ...
# 5405                            6                                          3
# 5406                           12                                          2
# 5407                           28                                          9
# 5408                            0                                          0
# 5409                           42                                         12
#
#       InscClaimAmtReimbursed1DeviationsGlobal  \
# 0                                           3
# 1                                          46
# 2                                           0
# 3                                           0
# 4                                           2
# ...                                       ...
# 5405                                        0
# 5406                                        0
# 5407                                        0
# 5408                                        0
# 5409                                        0
#
#       DeductibleAmtPaid1DeviationsInternal  \
# 0                                        5
# 1                                       62
# 2                                        6
# 3                                       45
# 4                                        3
# ...                                    ...
# 5405                                     2
# 5406                                     0
# 5407                                     6
# 5408                                     0
# 5409                                     6
#
#       DeductibleAmtPaid1DeviationsGlobal  \
# 0                                      5
# 1                                     62
# 2                                      0
# 3                                      0
# 4                                      3
# ...                                  ...
# 5405                                   0
# 5406                                   0
# 5407                                   0
# 5408                                   0
# 5409                                   0
#
#       IPAnnualReimbursementAmt1DeviationsInternal  \
# 0                                               3
# 1                                              16
# 2                                              16
# 3                                              90
# 4                                              12
# ...                                           ...
# 5405                                            4
# 5406                                            8
# 5407                                            9
# 5408                                            0
# 5409                                           13
#
#       IPAnnualReimbursementAmt1DeviationsGlobal  \
# 0                                             4
# 1                                            16
# 2                                            14
# 3                                            57
# 4                                             2
# ...                                         ...
# 5405                                          3
# 5406                                          0
# 5407                                         11
# 5408                                          0
# 5409                                          6
#
#       OPAnnualReimbursementAmt1DeviationsInternal  \
# 0                                               3
# 1                                               9
# 2                                              14
# 3                                              49
# 4                                              21
# ...                                           ...
# 5405                                            3
# 5406                                            3
# 5407                                            7
# 5408                                            0
# 5409                                            6
#
#       OPAnnualReimbursementAmt1DeviationsGlobal
# 0                                             2
# 1                                            10
# 2                                            13
# 3                                            49
# 4                                             0
# ...                                         ...
# 5405                                          5
# 5406                                          0
# 5407                                          8
# 5408                                          0
# 5409                                         16
#
# [5410 rows x 84 columns]

# %% [markdown]
# # Define independent variables
#
# Based on prior statistical evaluation and experimentation, we select independent variables to include in the model.

# %%
features = ['MeanInscClaimAmtReimbursed', 'MedianInscClaimAmtReimbursed', 'StdInscClaimAmtReimbursed','MaxInscClaimAmtReimbursed','MeanPatientAge','MedianPatientAge','StdPatientAge','MinPatientAge','MaxPatientAge','MeanGender','MeanRace','MeanPatientStayDur', 'MaxPatientStayDur','PatientAge1DeviationsInternal','PatientAge1DeviationsGlobal','InscClaimAmtReimbursed1DeviationsInternal','InscClaimAmtReimbursed1DeviationsGlobal', 'VarIPAnnualReimbursementAmt', 'VarOPAnnualReimbursementAmt']

X_final_frame = final_frame.reindex(columns=features)
X_final_frame
# Out:
#       MeanInscClaimAmtReimbursed  MedianInscClaimAmtReimbursed  \
# 0                    4185.600000                           400
# 1                    4588.409091                          1750
# 2                     350.134228                            70
# 3                     241.124464                            70
# 4                     468.194444                            80
# ...                          ...                           ...
# 5405                  380.000000                            65
# 5406                  216.818182                            85
# 5407                  225.243902                            70
# 5408                 1900.000000                          1900
# 5409                  369.576271                            90
#
#       StdInscClaimAmtReimbursed  MaxInscClaimAmtReimbursed  MeanPatientAge  \
# 0                  10796.091144                      42000       78.263014
# 1                   7309.794729                      57000       69.587422
# 2                    689.963754                       3300       71.787570
# 3                    491.556392                       4080       70.075247
# 4                   1433.769116                      10000       68.837291
# ...                         ...                        ...             ...
# 5405                 820.880286                       3300       73.476419
# 5406                 309.998254                       1100       61.016438
# 5407                 418.366092                       2200       71.545306
# 5408                   0.000000                       1900       67.786301
# 5409                 676.011928                       3300       73.643046
#
#       MedianPatientAge  StdPatientAge  MinPatientAge  MaxPatientAge  \
# 0            79.558904      11.919149      57.073973      97.539726
# 1            71.686301      13.467381      37.671233      96.958904
# 2            72.830137      12.929491      25.794521      99.758904
# 3            70.731507      13.352600      28.438356     100.887671
# 4            70.030137      14.634557      26.010959      99.210959
# ...                ...            ...            ...            ...
# 5405         72.553425       8.788619      55.863014      89.282192
# 5406         58.689041       9.804038      43.383562      82.449315
# 5407         73.606849      16.522107      30.145205      98.682192
# 5408         67.786301       0.000000      67.786301      67.786301
# 5409         73.032877      13.677455      43.063014      99.230137
#
#       MeanGender  MeanRace  MeanPatientStayDur  MaxPatientStayDur  \
# 0       1.640000  1.160000            1.000000               14.0
# 1       1.590909  1.212121            2.424242               27.0
# 2       1.691275  1.228188            0.000000                0.0
# 3       1.561373  1.242060            0.000000                0.0
# 4       1.527778  1.194444            0.222222                7.0
# ...          ...       ...                 ...                ...
# 5405    1.428571  1.642857            0.000000                0.0
# 5406    1.227273  1.181818            0.000000                0.0
# 5407    1.512195  1.304878            0.000000                0.0
# 5408    1.000000  1.000000            0.000000                0.0
# 5409    1.525424  1.203390            0.000000                0.0
#
#       PatientAge1DeviationsInternal  PatientAge1DeviationsGlobal  \
# 0                                 8                           10
# 1                                39                           43
# 2                                50                           47
# 3                               306                          305
# 4                                19                           24
# ...                             ...                          ...
# 5405                              8                            6
# 5406                              6                           12
# 5407                             23                           28
# 5408                              0                            0
# 5409                             40                           42
#
#       InscClaimAmtReimbursed1DeviationsInternal  \
# 0                                             2
# 1                                            17
# 2                                            15
# 3                                            92
# 4                                             4
# ...                                         ...
# 5405                                          3
# 5406                                          2
# 5407                                          9
# 5408                                          0
# 5409                                         12
#
#       InscClaimAmtReimbursed1DeviationsGlobal  VarIPAnnualReimbursementAmt  \
# 0                                           3                 1.512858e+09
# 1                                          46                 1.008212e+08
# 2                                           0                 9.780346e+07
# 3                                           0                 9.386755e+07
# 4                                           2                 3.229149e+07
# ...                                       ...                          ...
# 5405                                        0                 7.539154e+07
# 5406                                        0                 1.216344e+07
# 5407                                        0                 2.169850e+08
# 5408                                        0                 0.000000e+00
# 5409                                        0                 6.865767e+07
#
#       VarOPAnnualReimbursementAmt
# 0                    8.845726e+06
# 1                    2.694352e+07
# 2                    1.022727e+07
# 3                    1.568327e+07
# 4                    2.636972e+06
# ...                           ...
# 5405                 1.821784e+07
# 5406                 2.063478e+06
# 5407                 1.946157e+07
# 5408                 0.000000e+00
# 5409                 2.588769e+07
#
# [5410 rows x 19 columns]

# %% [markdown]
# # Define dependent variables
#
# Define the dependent variables that we are trying to predict

# %%
Y_final_frame = final_frame['PotentialFraud']
Y_final_frame
# Out:
# 0        No
# 1       Yes
# 2        No
# 3       Yes
# 4        No
#        ...
# 5405     No
# 5406     No
# 5407     No
# 5408     No
# 5409     No
# Name: PotentialFraud, Length: 5410, dtype: object

# %% [markdown]
# # Split training and test data
#
# Separate training and test data prior to computing the decision tree

# %%
from sklearn.model_selection import train_test_split as tts

X, XTest, Y, YTest = tts(X_final_frame, Y_final_frame, test_size =0.60, random_state=42)

import numpy as np
sorted_out = Y.unique()
sorted_out = np.sort(sorted_out)
sorted_out = list(map(str, sorted_out))

# %%
XTest
# Out:
#       MeanInscClaimAmtReimbursed  MedianInscClaimAmtReimbursed  \
# 290                   321.754386                            70
# 1730                  101.428571                            60
# 4235                  300.000000                            35
# 4870                 1170.833333                            60
# 1073                 2991.697248                           100
# ...                          ...                           ...
# 1821                 2293.070175                           100
# 1494                  331.986301                            70
# 2401                  146.666667                           100
# 1232                  400.000000                           200
# 2661                   87.500000                            70
#
#       StdInscClaimAmtReimbursed  MaxInscClaimAmtReimbursed  MeanPatientAge  \
# 290                  700.405808                       4100       69.287479
# 1730                 107.924136                        300       76.520939
# 4235                 533.354166                       1100       71.932192
# 4870                2899.543721                      10000       79.496804
# 1073                8097.274467                      57000       73.975418
# ...                         ...                        ...             ...
# 1821                4660.931261                      39000       72.313572
# 1494                1396.542341                      16000       74.107300
# 2401                 136.137186                        300       76.350685
# 1232                 616.508194                       2300       76.187062
# 2661                  83.815273                        200       76.813699
#
#       MedianPatientAge  StdPatientAge  MinPatientAge  MaxPatientAge  \
# 290          73.323288      15.751870      26.389041      94.819178
# 1730         79.860274       5.700745      67.293151      82.621918
# 4235         72.442466       4.752965      66.005479      76.838356
# 4870         78.923288      11.172031      60.249315      99.912329
# 1073         73.854795      12.315916      29.128767     100.282192
# ...                ...            ...            ...            ...
# 1821         73.821918      12.838412      25.621918     100.901370
# 1494         71.180822      11.832505      47.942466      98.468493
# 2401         76.416438       5.370165      70.947945      81.687671
# 1232         78.413699      11.120744      51.997260      88.309589
# 2661         72.839726      10.375726      69.613699      91.961644
#
#       MeanGender  MeanRace  MeanPatientStayDur  MaxPatientStayDur  \
# 290     1.561404  1.578947            0.000000                0.0
# 1730    1.571429  1.428571            0.000000                0.0
# 4235    1.500000  1.000000            0.000000                0.0
# 4870    1.666667  1.000000            0.166667                2.0
# 1073    1.610092  1.256881            1.545872               26.0
# ...          ...       ...                 ...                ...
# 1821    1.563596  1.107456            1.335526               26.0
# 1494    1.650685  1.075342            0.034247                5.0
# 2401    1.333333  1.000000            0.000000                0.0
# 1232    1.666667  1.000000            0.000000                0.0
# 2661    1.250000  1.000000            0.000000                0.0
#
#       PatientAge1DeviationsInternal  PatientAge1DeviationsGlobal  \
# 290                              18                           20
# 1730                              2                            0
# 4235                              2                            0
# 4870                              3                            4
# 1073                             63                           58
# ...                             ...                          ...
# 1821                            127                          123
# 1494                             52                           41
# 2401                              1                            0
# 1232                              8                            8
# 2661                              1                            1
#
#       InscClaimAmtReimbursed1DeviationsInternal  \
# 290                                           5
# 1730                                          1
# 4235                                          1
# 4870                                          1
# 1073                                         15
# ...                                         ...
# 1821                                         62
# 1494                                          5
# 2401                                          1
# 1232                                          2
# 2661                                          1
#
#       InscClaimAmtReimbursed1DeviationsGlobal  VarIPAnnualReimbursementAmt  \
# 290                                         0                 4.637595e+07
# 1730                                        0                 7.557143e+07
# 4235                                        0                 6.746702e+08
# 4870                                        1                 4.816061e+08
# 1073                                       36                 2.818024e+08
# ...                                       ...                          ...
# 1821                                       84                 9.378695e+07
# 1494                                        1                 6.675469e+07
# 2401                                        0                 0.000000e+00
# 1232                                        0                 1.032818e+07
# 2661                                        0                 9.120400e+06
#
#       VarOPAnnualReimbursementAmt
# 290                  3.848727e+06
# 1730                 7.220619e+05
# 4235                 3.602000e+05
# 4870                 3.603299e+06
# 1073                 9.404526e+06
# ...                           ...
# 1821                 1.818664e+07
# 1494                 4.448641e+06
# 2401                 1.203733e+06
# 1232                 8.932598e+06
# 2661                 8.124367e+06
#
# [3246 rows x 19 columns]

# %%
YTest
# Out:
# 290      No
# 1730     No
# 4235     No
# 4870     No
# 1073     No
#        ...
# 1821    Yes
# 1494     No
# 2401     No
# 1232     No
# 2661     No
# Name: PotentialFraud, Length: 3246, dtype: object

# %% [markdown]
# # Helper functions for models
#
# We will be running several iterations of decision tree variants. These helper functions reduce the amount of code we have to manage.

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import plot_confusion_matrix as matrix
from sklearn.model_selection import KFold

def create_confusion_matrix(classifier, x_test, y_test, labels):
    figSize = plt.rcParams["figure.figsize"]
    figSize[0] = 30
    figSize[1] = 5
    plt.rcParams["figure.figsize"]=figSize
    print(plt.rcParams.get('figure.figsize'))

    #plot the confusion matrices 1 for normalzied the other un-normalized
    values = ['true',None]
    #cmap='cividis'
    for x in values:
        disp = matrix(classifier,x_test,y_test,display_labels=labels,normalize=x)
        disp.ax_.set_title("Confusion matrix with normalization = "+str(x))
    print(disp.confusion_matrix)

def get_false_negatives(x_test, y_test, y_predicted):
    return x_test[(y_test != y_predicted) & (y_predicted == "No")]

def get_false_positives(x_test, y_test, y_predicted):
    return x_test[(y_test != y_predicted) & (y_predicted == "Yes")]

def kfold_cross_validate(classifier, x_data, y_data):
    kf_train= KFold(n_splits=5, shuffle=True, random_state=10)

    max_scr = 0
    for train_idx, test_idx in kf_train.split(x_data):
        X_trn = x_data.iloc[train_idx]
        Y_trn = y_data.iloc[train_idx]
        X_tst = x_data.iloc[test_idx]
        Y_tst = y_data.iloc[test_idx]
        model = classifier.fit(X_trn, Y_trn)
        score = model.score(X_tst, Y_tst)
        print("Model Score={}".format(score))
        if score > max_scr:
            max_scr = score
            model_max = model
    
    return (max_scr, model_max)

# %% [markdown]
# # Compute single decision tree
#
# Use the sklearn implementation of the decision tree classifier algorithm to build a decision tree from training data

# %%
import sklearn
print('The scikit-learn version is {}.'.format(sklearn.__version__))
from sklearn import tree

dtree_clf = tree.DecisionTreeClassifier(random_state=0)

##Cant have any chracters in these fields, must be numbers
dtree_clf = dtree_clf.fit(X, Y)
dtree_clf
# Out:
# The scikit-learn version is 0.23.2.
# DecisionTreeClassifier(random_state=0)

# %% [markdown]
# ## Plot the decision tree created by sklearn

# %%
import matplotlib.pyplot as plt

fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 20
fig_size[1] = 20
plt.rcParams["figure.figsize"] = fig_size

print(dtree_clf.get_n_leaves())

plot = tree.plot_tree(dtree_clf, rounded=True, filled=True, class_names=sorted_out, feature_names=features, max_depth=2)
# Out:
# 103

# %%
YPredicted_dtree = dtree_clf.predict(XTest)
YPredicted_dtree
# Out:
# array(['No', 'No', 'No', ..., 'No', 'No', 'No'], dtype=object)

# %% [markdown]
# ## Compute model accuracy (single decision tree)

# %%
from sklearn import metrics
accuracy = metrics.accuracy_score(YTest, YPredicted_dtree)
accuracy
# Out:
# 0.9171287738755391

# %% [markdown]
# ## Display confusion matrix (single decision tree)

# %%
create_confusion_matrix(dtree_clf, XTest, YTest, sorted_out)
# Out:
# [30.0, 5.0]
# [[2816  125]
#  [ 144  161]]

# %% [markdown]
# ## Display error class information (false pos. / false neg.)

# %%
dtree_fp = get_false_positives(XTest, YTest, YPredicted_dtree)
print(f'False Positive count = {len(dtree_fp)}')
# Out:
# False Positive count = 125

# %%
dtree_fn = get_false_negatives(XTest, YTest, YPredicted_dtree)
print(f'False Negative count = {len(dtree_fn)}')
# Out:
# False Negative count = 144

# %% [markdown]
# # Perform k-folds cross-validation on decision tree model

# %%
best_score, dtree_clf_kfold = kfold_cross_validate(dtree_clf, X, Y)
print(f'Best model score = {best_score}')
# Out:
# Model Score=0.9284064665127021
# Model Score=0.9030023094688222
# Model Score=0.9168591224018475
# Model Score=0.9076212471131639
# Model Score=0.9004629629629629
# Best model score = 0.9284064665127021

# %% [markdown]
# ## Compute model accuracy (single decision tree, k-folds cross-validated)

# %%
YPredicted_dtree_kfold = dtree_clf_kfold.predict(XTest)
accuracy = metrics.accuracy_score(YTest, YPredicted_dtree_kfold)
accuracy
# Out:
# 0.9162045594577942

# %% [markdown]
# ## Display confusion matrix (single decision tree, k-folds cross-validated)

# %%
create_confusion_matrix(dtree_clf_kfold, XTest, YTest, sorted_out)
# Out:
# [30.0, 5.0]
# [[2775  166]
#  [ 106  199]]

# %% [markdown]
# ## Display error class information (false pos. / false neg.)

# %%
dtree_kf_fp = get_false_positives(XTest, YTest, YPredicted_dtree_kfold)
print(f'False Positive count = {len(dtree_kf_fp)}')
# Out:
# False Positive count = 166

# %%
dtree_kf_fn = get_false_negatives(XTest, YTest, YPredicted_dtree_kfold)
print(f'False Negative count = {len(dtree_kf_fn)}')
# Out:
# False Negative count = 106

# %% [markdown]
# ## Display relative importance of features in the decision tree model

# %%
sorted([x for x in zip(dtree_clf_kfold.feature_importances_, features)], key=lambda x: x[0])
# Out:
# [(0.012001108647450106, 'MeanRace'),
#  (0.01242540889664861, 'PatientAge1DeviationsGlobal'),
#  (0.019396936129371847, 'MedianInscClaimAmtReimbursed'),
#  (0.020003332331906112, 'MeanInscClaimAmtReimbursed'),
#  (0.022944953567117427, 'MaxPatientAge'),
#  (0.023378510861771465, 'MinPatientAge'),
#  (0.024223474705044063, 'MeanPatientAge'),
#  (0.025624052209020386, 'MedianPatientAge'),
#  (0.02594887461390123, 'VarIPAnnualReimbursementAmt'),
#  (0.02659448324660232, 'MeanGender'),
#  (0.029420425721940424, 'MeanPatientStayDur'),
#  (0.034124825206789625, 'VarOPAnnualReimbursementAmt'),
#  (0.038772552506239975, 'InscClaimAmtReimbursed1DeviationsInternal'),
#  (0.04556872911470423, 'StdPatientAge'),
#  (0.047637102875550535, 'InscClaimAmtReimbursed1DeviationsGlobal'),
#  (0.07173202023161297, 'MaxInscClaimAmtReimbursed'),
#  (0.07223021312304137, 'StdInscClaimAmtReimbursed'),
#  (0.08675335710680822, 'PatientAge1DeviationsInternal'),
#  (0.361219638904479, 'MaxPatientStayDur')]

# %% [markdown]
# # Compute random forest classifier with 100 estimators (decision trees)
#
# Use the sklearn implementation of the decision tree classifier algorithm to build a decision tree from training data

# %%
from sklearn import ensemble
rfor_clf = ensemble.RandomForestClassifier(n_estimators=100, random_state=0)

rfor_clf = rfor_clf.fit(X, Y)
rfor_clf
# Out:
# RandomForestClassifier(random_state=0)

# %%
YPredicted_rfor = rfor_clf.predict(XTest)
YPredicted_rfor
# Out:
# array(['No', 'No', 'No', ..., 'No', 'No', 'No'], dtype=object)

# %% [markdown]
# ## Compute model accuracy (random forest, n=100)

# %%
from sklearn import metrics
accuracy = metrics.accuracy_score(YTest, YPredicted_rfor)
accuracy
# Out:
# 0.9393099199014171

# %% [markdown]
# ## Display confusion matrix (random forest, n=100)

# %%
create_confusion_matrix(rfor_clf, XTest, YTest, sorted_out)
# Out:
# [30.0, 5.0]
# [[2899   42]
#  [ 155  150]]

# %% [markdown]
# ## Display error class information (false pos. / false neg.)

# %%
rfor_fp = get_false_positives(XTest, YTest, YPredicted_rfor)
print(f'False Positive count = {len(rfor_fp)}')
# Out:
# False Positive count = 42

# %%
rfor_fn = get_false_negatives(XTest, YTest, YPredicted_rfor)
print(f'False Negative count = {len(rfor_fn)}')
# Out:
# False Negative count = 155

# %% [markdown]
# # Perform k-folds cross-validation on random forest model

# %%
best_score, rfor_clf_kfold = kfold_cross_validate(rfor_clf, X, Y)
print(f'Best model score = {best_score}')
# Out:
# Model Score=0.9284064665127021
# Model Score=0.9468822170900693
# Model Score=0.930715935334873
# Model Score=0.9214780600461894
# Model Score=0.9305555555555556
# Best model score = 0.9468822170900693

# %% [markdown]
# ## Compute model accuracy (random forest, n=100, k-folds cross-validated)

# %%
YPredicted_rfor_kfold = rfor_clf_kfold.predict(XTest)
accuracy = metrics.accuracy_score(YTest, YPredicted_rfor_kfold)
accuracy
# Out:
# 0.9365372766481824

# %% [markdown]
# ## Display confusion matrix (random forest, n=100, k-folds cross-validated)

# %%
create_confusion_matrix(rfor_clf_kfold, XTest, YTest, sorted_out)
# Out:
# [30.0, 5.0]
# [[2875   66]
#  [ 140  165]]

# %% [markdown]
# ## Display error class information (false pos. / false neg.)

# %%
rfor_kf_fp = get_false_positives(XTest, YTest, YPredicted_rfor_kfold)
print(f'False Positive count = {len(rfor_kf_fp)}')
# Out:
# False Positive count = 66

# %%
rfor_kf_fn = get_false_negatives(XTest, YTest, YPredicted_rfor_kfold)
print(f'False Negative count = {len(rfor_kf_fn)}')
# Out:
# False Negative count = 140

# %% [markdown]
# ## Display relative importance of features in the decision tree model

# %%
sorted([x for x in zip(rfor_clf_kfold.feature_importances_, features)], key=lambda x: x[0])
# Out:
# [(0.019238555954209997, 'MedianInscClaimAmtReimbursed'),
#  (0.026504141041963428, 'MeanRace'),
#  (0.028619264969303056, 'MeanGender'),
#  (0.02975207947970802, 'MaxPatientAge'),
#  (0.03065345784836248, 'MeanPatientAge'),
#  (0.031203333993828, 'MeanPatientStayDur'),
#  (0.032708818105235044, 'VarIPAnnualReimbursementAmt'),
#  (0.03382833263931718, 'StdPatientAge'),
#  (0.033921081280660605, 'MedianPatientAge'),
#  (0.03528899852296371, 'MinPatientAge'),
#  (0.0361990021728984, 'VarOPAnnualReimbursementAmt'),
#  (0.03912968539993932, 'MeanInscClaimAmtReimbursed'),
#  (0.049135449358837444, 'InscClaimAmtReimbursed1DeviationsInternal'),
#  (0.05856495982046443, 'PatientAge1DeviationsGlobal'),
#  (0.0595708713686906, 'StdInscClaimAmtReimbursed'),
#  (0.06120919447181397, 'PatientAge1DeviationsInternal'),
#  (0.08204464286251675, 'MaxInscClaimAmtReimbursed'),
#  (0.14216050813782338, 'InscClaimAmtReimbursed1DeviationsGlobal'),
#  (0.17026762257146413, 'MaxPatientStayDur')]

# %% [markdown]
# # Summarize findings!

# %%
from sklearn.metrics import classification_report
print(classification_report(YTest, YPredicted_rfor_kfold))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.95      0.98      0.97      2941
#          Yes       0.71      0.54      0.62       305
#
#     accuracy                           0.94      3246
#    macro avg       0.83      0.76      0.79      3246
# weighted avg       0.93      0.94      0.93      3246

# %% [markdown]
# Our Model is extremely good in predicting Legitimate medical providers but not as much in detecting fraudulent ones. A Fraud Precision of 0.71 indicates 29% of the times this model labels some provider as Fraud, it may actually turn out to be a good provider. And a Fraud Recall of 0.53 indicates the model can catch actual fraulent providers only 53% of the times.
